# %% [markdown]
# # Technical Requirements

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import warnings

plt.rcParams["figure.figsize"] = [14, 7]
warnings.filterwarnings('ignore')

# %%
path = Path('../../datasets/Ch13/')
energy = pd.read_csv(path.joinpath('energy_consumption.csv'), 
                     index_col='Month', 
                     parse_dates=True)

energy.columns = ['y'] # rename column for clarity
energy.index.freq = 'MS' #set frequency
energy.plot(title='Monthly Energy Consumption')
plt.xlabel('Month')
plt.ylabel('Energy Consumption')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
print("Original Data Info:")
energy.info()
print(f"\nOriginal Data Head:\n{energy.head()}")
# Out:
# Original Data Info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 588 entries, 1973-01-01 to 2021-12-01
# Freq: MS
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   y       588 non-null    float64
# dtypes: float64(1)
# memory usage: 9.2 KB
#
# Original Data Head:
#                    y
# Month
# 1973-01-01  1957.641
# 1973-02-01  1712.143
# 1973-03-01  1510.079
# 1973-04-01  1183.421
# 1973-05-01  1006.326

# %%
# --- Preprocessing Functions ---

def fill_missing_forward(df):
    """
    Checks for missing data and fills using forward fill.

    Args:
        df (pd.DataFrame): DataFrame with a time series in a column named 'y'

    Returns:
        pd.DataFrame: DataFrame with missing values filled.
    """
    n_missing = int(df['y'].isna().sum()) # Assuming single column 'y'
    if n_missing > 0:
        print(f'Found {n_missing} missing observations... filling forward.')
        df = df.ffill()
    return df

# %%
en_df = fill_missing_forward(energy)

# %% [markdown]
# # Forecasting with LSTM

# %% [markdown]
# ## Using Keras: One-Step Forecasting (Short-Term)

# %%
from tensorflow.keras import Sequential, Input
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import (EarlyStopping, 
                                        ReduceLROnPlateau, 
                                        TensorBoard,
                                        ModelCheckpoint)
from tensorflow.keras.metrics import RootMeanSquaredError, MeanAbsoluteError

# %%
# This is added for Reproducibility
import random 
import tensorflow as tf

SEED = 42 
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

# %%
def create_sequences(df, window_size, target_col='y'):
    """
    Convert a time series into a supervised learning dataset with lagged features.
    
    Parameters:
    -----------
    df : pandas.DataFrame
        Time series data with single target column
    window_size : int
        Number of lagged observations to use as input features
    target_col : str, optional
        Name of the column in 'df' that contains the target time series values.
        Default is 'y'
        
    Returns:
    --------
    pandas.DataFrame
        DataFrame with lagged features (x1, x2, ...) and target (y)
    """
    try:
        # Extract the target column as a 1D NumPy array
        data_values = df[target_col].values 
    except KeyError:
        raise KeyError(f"""Column '{target_col}' not found in DataFrame. 
                        Please ensure the target column is correctly named.""")

    X_list = [data_values[i:i+window_size] for i in range(len(data_values)-window_size)]
    X = np.array(X_list) # Creates a 2D array (num_sequences, window_size)
    
    # Target is the value immediately following each window
    y_values = data_values[window_size:]
    idx = df.index[window_size:]

    feature_cols = [f'x{i+1}' for i in range(window_size)]

    seq_df = pd.DataFrame(X, columns=feature_cols, index=idx)
    # Assign the target values to a column named 'y' in the new DataFrame
    seq_df['y'] = y_values

    return seq_df

# %%
en_seq = create_sequences(en_df, 12)
en_seq.head()
# Out:
#                   x1        x2        x3        x4        x5       x6  \
# Month
# 1974-01-01  1957.641  1712.143  1510.079  1183.421  1006.326  914.949
# 1974-02-01  1712.143  1510.079  1183.421  1006.326   914.949  961.872
# 1974-03-01  1510.079  1183.421  1006.326   914.949   961.872  994.259
# 1974-04-01  1183.421  1006.326   914.949   961.872   994.259  937.083
# 1974-05-01  1006.326   914.949   961.872   994.259   937.083  978.162
#
#                   x7        x8        x9       x10       x11       x12  \
# Month
# 1974-01-01   961.872   994.259   937.083   978.162  1202.105  1538.568
# 1974-02-01   994.259   937.083   978.162  1202.105  1538.568  1846.930
# 1974-03-01   937.083   978.162  1202.105  1538.568  1846.930  1589.448
# 1974-04-01   978.162  1202.105  1538.568  1846.930  1589.448  1451.073
# 1974-05-01  1202.105  1538.568  1846.930  1589.448  1451.073  1215.228
#
#                    y
# Month
# 1974-01-01  1846.930
# 1974-02-01  1589.448
# 1974-03-01  1451.073
# 1974-04-01  1215.228
# 1974-05-01  1003.821

# %%
en_seq.shape
# Out:
# (576, 13)

# %%
class TimeSeriesStandardScaler:
    """
    Standardizes time series data and provides train/val/test splits.
    """
    def __init__(self, df, test_size, val_size):
        """
        Initializes the preprocessor.

        Args:
            df (pd.DataFrame): The DataFrame containing sequences (features and target).
            test_size (int): Number of periods for the test set.
            val_size (int): Number of periods for the validation set.
        """
        self.data = df
        self.test_periods = test_size
        self.val_periods = val_size
        self.mu = None
        self.sigma = None
    
    def split_data(self):
        """
        Splits the data into training, validation, and test sets based on time order.
        """
        n_total = len(self.data)
        
        test_start = n_total - self.test_periods
        val_start = test_start - self.val_periods
        # Create splits maintaining temporal order
        train = self.data.iloc[:val_start]
        val = self.data.iloc[val_start:test_start]
        test = self.data.iloc[test_start:]
             
        assert len(test) + len(train) + len(val) == len(self.data)
        return train, val, test
    
    def _transform(self, data):
        if self.mu is None or self.sigma is None:
            raise ValueError("Scaler not fitted yet. Call fit_transform() first.")
        data_s = (data - self.mu)/self.sigma
        return data_s
    
    def fit_transform(self):
        """
        Fits the scaler on the training data and transforms train, val, and test sets.
        Scales all features and target using the same parameters derived from the training data.
        """
        train, val, test = self.split_data()
        self.mu, self.sigma = train.mean(), train.std()
        train_scaled = self._transform(train)
        test_scaled = self._transform(test)
        val_scaled = self._transform(val)
        return train_scaled, val_scaled, test_scaled
    
    def inverse_transform(self, data):
        """
        Reverses the standardization transformation.
        """
        return (data * self.sigma)+self.mu
        
    def inverse_transform_target(self, data):
        """
        Reverses standardization for target variable only.
        Assumes target is the last column in the original DataFrame.
        """
        return (data * self.sigma[-1])+self.mu[-1]

# %%
scaler = TimeSeriesStandardScaler(en_seq, test_size=12, val_size=36)
k_train_scaled, k_val_scaled, k_test_scaled = scaler.fit_transform()

# %%
print(f'''
original: {energy.shape}
sequence_df: {en_seq.shape}
train_scaled: {k_train_scaled.shape}
val_scaled: {k_val_scaled.shape}
test_scaled: {k_test_scaled.shape}
''')
# Out:
# original: (588, 1)
# sequence_df: (576, 13)
# train_scaled: (528, 13)
# val_scaled: (36, 13)
# test_scaled: (12, 13)

# %%
def prepare_keras_input(*args):
    """
    Converts DataFrames to 3D tensors for LSTM models.
    
    Parameters:
    -----------
    *args : list of pandas.DataFrame
        DataFrames with:
            - Feature columns (x1, x2, ...)
            - Target column 'y'   
    Returns:
    --------
    tuple
        Tuple containing target arrays followed by feature arrays for each input DataFrame
    """
    y = [col.pop('y').values.reshape(-1, 1) for col in args]
    x = [col.values.reshape(*col.shape, 1) for col in args]
    
    return *y, *x

# %%
 # For Keras/TensorFlow
(y_train_k, 
 y_val_k, 
 y_test_k, 
 x_train_k, 
 x_val_k, 
 x_test_k) = prepare_keras_input(k_train_scaled.copy(), 
                                  k_val_scaled.copy(), 
                                  k_test_scaled.copy())

# %%
print(f"x_train_k shape: {x_train_k.shape}")  
print(f"y_train_k shape: {y_train_k.shape}")
# Out:
# x_train_k shape: (528, 12, 1)
# y_train_k shape: (528, 1)

# %% [markdown]
# ```python
# model = Sequential()
# model.add(Input(shape=input_shape))
# model.add(LSTM(units=units))
# model.add(Dense(1))
# ```
#
# adding Dropout
#
# ```python
# model = Sequential()
# model.add(Input(shape=input_shape))
# model.add(LSTM(units=units))
# model.add(Dropout(dropout_rate))
# model.add(Dense(1))
# ```
#
# adding another LSTM and Dropout layers
#
# ```python
# model = Sequential()
# model.add(Input(shape=input_shape))
# model.add(LSTM(units=units, return_sequences=True))
# model.add(Dropout(dropout_rate))
# model.add(LSTM(units=units//2))  # Second LSTM layer with fewer units
# model.add(Dropout(dropout_rate))
# model.add(Dense(1))
# ```

# %%
def create_keras_lstm_model(input_shape, units=32, dropout_rate=0.2):
    """
    Creates a stacked Keras LSTM model for time series forecasting.

    Args:
        input_shape (tuple): Shape of the input data (timesteps, features). Example: (WINDOW_SIZE, 1).
        units (int): Number of units in the first LSTM layer.
                     The second LSTM layer will use units//2
        dropout_rate (float): Dropout rate after each LSTM layer.
    Returns:
        keras.Model: Compiled Keras model.
    """
    model = Sequential()
    # Input shape expected by LSTM: (batch_size, timesteps, features)
    # We provide (timesteps, features) via input_shape
    model.add(Input(shape=input_shape))
    model.add(LSTM(units=units, return_sequences=True))
    model.add(Dropout(dropout_rate))
    model.add(LSTM(units=units))  # Second LSTM layer with fewer units
    model.add(Dropout(dropout_rate))
    model.add(Dense(1)) # Output layer for forecasting

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                  loss='mean_squared_error',
                  metrics=[RootMeanSquaredError(name='rmse'),
                           MeanAbsoluteError(name='mae')])
    return model

# %%
keras_input_shape = (x_train_k.shape[1], x_train_k.shape[2])

keras_lstm_model = create_keras_lstm_model(input_shape=keras_input_shape,
                                     units=32,
                                     dropout_rate=0.2)
keras_lstm_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 12, 32)         │         4,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 12, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,705 (49.63 KB)
#  Trainable params: 12,705 (49.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
def train_keras_model(model, x_train, y_train, x_val, y_val,
                      epochs=500, 
                      patience=15,
                      batch_size=32):
    """
    Trains the Keras model with early stopping.

    Args:
        model (keras.Model): The compiled Keras model.
        x_train, y_train: Training data and targets.
        x_val, y_val: Validation data and targets.
        epochs (int): Maximum number of training epochs.
        patience (int): Number of epochs with no improvement to wait before stopping.
        batch_size (int): Training batch size.

    Returns:
        keras.callbacks.History: Training history object.
    """
    print(f"\nTraining Keras model for max {epochs} epochs (patience={patience}, batch_size={batch_size})...")
    early_stopping = EarlyStopping(monitor="val_loss",
                                   patience=patience,
                                   min_delta=0.001, # Small improvement threshold
                                   restore_best_weights=True, # Restore weights from best epoch
                                   verbose=1) 

    # persisting model best weights
    model_checkpoint = ModelCheckpoint(
        filepath='./logs/best_model.keras',
        monitor="val_loss",
        save_best_only=True,
        mode="min",
        verbose=1,
        save_freq="epoch")

    reduce_lr = ReduceLROnPlateau(monitor='val_loss', 
                                  factor=0.2, 
                                  patience=patience//3, 
                                  min_lr=1e-6,
                                  verbose=1)
    
    tensorboard= TensorBoard(log_dir='./logs', 
                             histogram_freq=1)

    history = model.fit(x_train, y_train,
                        shuffle=False, # Important for time series
                        epochs=epochs,
                        batch_size=batch_size,
                        validation_data=(x_val, y_val),
                        callbacks=[early_stopping, 
                                   reduce_lr, 
                                   tensorboard,
                                   model_checkpoint],
                        verbose=1) # Set to 1 or 2 for progress, 0 for silent
    print("Keras training complete.")
    return history

# %%
# %%time
history_lstm_keras = train_keras_model(
    keras_lstm_model,
    x_train_k, y_train_k,
    x_val_k, y_val_k,
    epochs=500,
    patience=15,
    batch_size=32)
# Out:
# Training Keras model for max 500 epochs (patience=15, batch_size=32)...
# Epoch 1/500
# 12/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0490 - mae: 0.9039 - rmse: 1.0219
# Epoch 1: val_loss improved from None to 0.97812, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.9953 - mae: 0.8018 - rmse: 0.9976 - val_loss: 0.9781 - val_mae: 0.7380 - val_rmse: 0.9890 - learning_rate: 0.0010
# Epoch 2/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8257 - mae: 0.8089 - rmse: 0.9081
# Epoch 2: val_loss improved from 0.97812 to 0.76389, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8124 - mae: 0.7595 - rmse: 0.9013 - val_loss: 0.7639 - val_mae: 0.6992 - val_rmse: 0.8740 - learning_rate: 0.0010
# Epoch 3/500
# 15/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6866 - mae: 0.6999 - rmse: 0.8280
# Epoch 3: val_loss improved from 0.76389 to 0.63694, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6880 - mae: 0.6955 - rmse: 0.8295 - val_loss: 0.6369 - val_mae: 0.6261 - val_rmse: 0.7981 - learning_rate: 0.0010
# Epoch 4/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5559 - mae: 0.6309 - rmse: 0.7451
# Epoch 4: val_loss improved from 0.63694 to 0.52541, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5632 - mae: 0.6106 - rmse: 0.7504 - val_loss: 0.5254 - val_mae: 0.5747 - val_rmse: 0.7249 - learning_rate: 0.0010
# Epoch 5/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4186 - mae: 0.5208 - rmse: 0.6465
# Epoch 5: val_loss improved from 0.52541 to 0.38177, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4534 - mae: 0.5332 - rmse: 0.6733 - val_loss: 0.3818 - val_mae: 0.4789 - val_rmse: 0.6179 - learning_rate: 0.0010
# Epoch 6/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4458 - mae: 0.5704 - rmse: 0.6664
# Epoch 6: val_loss improved from 0.38177 to 0.33363, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4115 - mae: 0.5339 - rmse: 0.6415 - val_loss: 0.3336 - val_mae: 0.4358 - val_rmse: 0.5776 - learning_rate: 0.0010
# Epoch 7/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3482 - mae: 0.4971 - rmse: 0.5896
# Epoch 7: val_loss did not improve from 0.33363
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4080 - mae: 0.5135 - rmse: 0.6388 - val_loss: 0.4433 - val_mae: 0.5127 - val_rmse: 0.6658 - learning_rate: 0.0010
# Epoch 8/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3270 - mae: 0.4668 - rmse: 0.5711
# Epoch 8: val_loss did not improve from 0.33363
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3811 - mae: 0.4885 - rmse: 0.6173 - val_loss: 0.3725 - val_mae: 0.4588 - val_rmse: 0.6104 - learning_rate: 0.0010
# Epoch 9/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3250 - mae: 0.4549 - rmse: 0.5692
# Epoch 9: val_loss did not improve from 0.33363
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3786 - mae: 0.4735 - rmse: 0.6153 - val_loss: 0.3893 - val_mae: 0.4903 - val_rmse: 0.6239 - learning_rate: 0.0010
# Epoch 10/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3184 - mae: 0.4721 - rmse: 0.5637
# Epoch 10: val_loss did not improve from 0.33363
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3462 - mae: 0.4721 - rmse: 0.5884 - val_loss: 0.3379 - val_mae: 0.4313 - val_rmse: 0.5813 - learning_rate: 0.0010
# Epoch 11/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2646 - mae: 0.3987 - rmse: 0.5130
# Epoch 11: val_loss improved from 0.33363 to 0.28044, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2972 - mae: 0.4227 - rmse: 0.5452 - val_loss: 0.2804 - val_mae: 0.4203 - val_rmse: 0.5296 - learning_rate: 0.0010
# Epoch 12/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3299 - mae: 0.4829 - rmse: 0.5735
# Epoch 12: val_loss improved from 0.28044 to 0.26821, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3158 - mae: 0.4586 - rmse: 0.5619 - val_loss: 0.2682 - val_mae: 0.4046 - val_rmse: 0.5179 - learning_rate: 0.0010
# Epoch 13/500
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2213 - mae: 0.3780 - rmse: 0.4700
# Epoch 13: val_loss did not improve from 0.26821
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2791 - mae: 0.4127 - rmse: 0.5283 - val_loss: 0.3031 - val_mae: 0.4152 - val_rmse: 0.5505 - learning_rate: 0.0010
# Epoch 14/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2860 - mae: 0.4323 - rmse: 0.5339
# Epoch 14: val_loss improved from 0.26821 to 0.26731, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2917 - mae: 0.4279 - rmse: 0.5401 - val_loss: 0.2673 - val_mae: 0.3971 - val_rmse: 0.5170 - learning_rate: 0.0010
# Epoch 15/500
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2320 - mae: 0.3916 - rmse: 0.4813
# Epoch 15: val_loss improved from 0.26731 to 0.24836, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2675 - mae: 0.4160 - rmse: 0.5172 - val_loss: 0.2484 - val_mae: 0.3903 - val_rmse: 0.4984 - learning_rate: 0.0010
# Epoch 16/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2337 - mae: 0.3949 - rmse: 0.4832
# Epoch 16: val_loss improved from 0.24836 to 0.22912, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2548 - mae: 0.4017 - rmse: 0.5047 - val_loss: 0.2291 - val_mae: 0.3696 - val_rmse: 0.4787 - learning_rate: 0.0010
# Epoch 17/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1897 - mae: 0.3508 - rmse: 0.4353
# Epoch 17: val_loss improved from 0.22912 to 0.22322, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2174 - mae: 0.3697 - rmse: 0.4663 - val_loss: 0.2232 - val_mae: 0.3641 - val_rmse: 0.4725 - learning_rate: 0.0010
# Epoch 18/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1897 - mae: 0.3585 - rmse: 0.4352
# Epoch 18: val_loss did not improve from 0.22322
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2249 - mae: 0.3747 - rmse: 0.4742 - val_loss: 0.2382 - val_mae: 0.3849 - val_rmse: 0.4880 - learning_rate: 0.0010
# Epoch 19/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2077 - mae: 0.3709 - rmse: 0.4552
# Epoch 19: val_loss improved from 0.22322 to 0.21647, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2318 - mae: 0.3860 - rmse: 0.4815 - val_loss: 0.2165 - val_mae: 0.3632 - val_rmse: 0.4653 - learning_rate: 0.0010
# Epoch 20/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1908 - mae: 0.3529 - rmse: 0.4364
# Epoch 20: val_loss improved from 0.21647 to 0.21292, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2152 - mae: 0.3660 - rmse: 0.4639 - val_loss: 0.2129 - val_mae: 0.3545 - val_rmse: 0.4614 - learning_rate: 0.0010
# Epoch 21/500
# 15/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1773 - mae: 0.3308 - rmse: 0.4206
# Epoch 21: val_loss did not improve from 0.21292
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2006 - mae: 0.3540 - rmse: 0.4479 - val_loss: 0.2282 - val_mae: 0.3817 - val_rmse: 0.4777 - learning_rate: 0.0010
# Epoch 22/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1895 - mae: 0.3417 - rmse: 0.4346
# Epoch 22: val_loss did not improve from 0.21292
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2211 - mae: 0.3653 - rmse: 0.4702 - val_loss: 0.2149 - val_mae: 0.3612 - val_rmse: 0.4636 - learning_rate: 0.0010
# Epoch 23/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2270 - mae: 0.3790 - rmse: 0.4750
# Epoch 23: val_loss did not improve from 0.21292
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2469 - mae: 0.3882 - rmse: 0.4969 - val_loss: 0.2840 - val_mae: 0.4171 - val_rmse: 0.5329 - learning_rate: 0.0010
# Epoch 24/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1754 - mae: 0.3302 - rmse: 0.4181
# Epoch 24: val_loss improved from 0.21292 to 0.20898, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1959 - mae: 0.3486 - rmse: 0.4426 - val_loss: 0.2090 - val_mae: 0.3618 - val_rmse: 0.4571 - learning_rate: 0.0010
# Epoch 25/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1419 - mae: 0.2976 - rmse: 0.3758
# Epoch 25: val_loss did not improve from 0.20898
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1857 - mae: 0.3427 - rmse: 0.4310 - val_loss: 0.2387 - val_mae: 0.3920 - val_rmse: 0.4885 - learning_rate: 0.0010
# Epoch 26/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2462 - mae: 0.3926 - rmse: 0.4932
# Epoch 26: val_loss improved from 0.20898 to 0.19991, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2244 - mae: 0.3772 - rmse: 0.4738 - val_loss: 0.1999 - val_mae: 0.3550 - val_rmse: 0.4471 - learning_rate: 0.0010
# Epoch 27/500
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1708 - mae: 0.3372 - rmse: 0.4128
# Epoch 27: val_loss improved from 0.19991 to 0.19825, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1803 - mae: 0.3410 - rmse: 0.4246 - val_loss: 0.1983 - val_mae: 0.3496 - val_rmse: 0.4453 - learning_rate: 0.0010
# Epoch 28/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1729 - mae: 0.3183 - rmse: 0.4147
# Epoch 28: val_loss did not improve from 0.19825
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1714 - mae: 0.3320 - rmse: 0.4140 - val_loss: 0.1985 - val_mae: 0.3496 - val_rmse: 0.4455 - learning_rate: 0.0010
# Epoch 29/500
# 13/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1409 - mae: 0.3008 - rmse: 0.3751
# Epoch 29: val_loss improved from 0.19825 to 0.17920, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1632 - mae: 0.3219 - rmse: 0.4040 - val_loss: 0.1792 - val_mae: 0.3321 - val_rmse: 0.4233 - learning_rate: 0.0010
# Epoch 30/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1587 - mae: 0.3261 - rmse: 0.3969
# Epoch 30: val_loss improved from 0.17920 to 0.17470, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1642 - mae: 0.3275 - rmse: 0.4052 - val_loss: 0.1747 - val_mae: 0.3307 - val_rmse: 0.4180 - learning_rate: 0.0010
# Epoch 31/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1388 - mae: 0.2982 - rmse: 0.3721
# Epoch 31: val_loss did not improve from 0.17470
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1668 - mae: 0.3239 - rmse: 0.4084 - val_loss: 0.2127 - val_mae: 0.3768 - val_rmse: 0.4612 - learning_rate: 0.0010
# Epoch 32/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1142 - mae: 0.2676 - rmse: 0.3374
# Epoch 32: val_loss did not improve from 0.17470
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1477 - mae: 0.3038 - rmse: 0.3843 - val_loss: 0.1915 - val_mae: 0.3531 - val_rmse: 0.4376 - learning_rate: 0.0010
# Epoch 33/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1299 - mae: 0.2846 - rmse: 0.3599
# Epoch 33: val_loss improved from 0.17470 to 0.17436, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1559 - mae: 0.3127 - rmse: 0.3948 - val_loss: 0.1744 - val_mae: 0.3287 - val_rmse: 0.4176 - learning_rate: 0.0010
# Epoch 34/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1247 - mae: 0.2830 - rmse: 0.3526
# Epoch 34: val_loss did not improve from 0.17436
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1502 - mae: 0.3095 - rmse: 0.3875 - val_loss: 0.1783 - val_mae: 0.3302 - val_rmse: 0.4223 - learning_rate: 0.0010
# Epoch 35/500
# 15/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1161 - mae: 0.2521 - rmse: 0.3401
# Epoch 35: val_loss did not improve from 0.17436
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1353 - mae: 0.2879 - rmse: 0.3679 - val_loss: 0.1802 - val_mae: 0.3358 - val_rmse: 0.4245 - learning_rate: 0.0010
# Epoch 36/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0983 - mae: 0.2413 - rmse: 0.3125
# Epoch 36: val_loss improved from 0.17436 to 0.17001, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1377 - mae: 0.2870 - rmse: 0.3711 - val_loss: 0.1700 - val_mae: 0.3258 - val_rmse: 0.4123 - learning_rate: 0.0010
# Epoch 37/500
# 15/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1095 - mae: 0.2617 - rmse: 0.3302
# Epoch 37: val_loss did not improve from 0.17001
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1398 - mae: 0.2916 - rmse: 0.3739 - val_loss: 0.1720 - val_mae: 0.3274 - val_rmse: 0.4147 - learning_rate: 0.0010
# Epoch 38/500
#  9/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1202 - mae: 0.2625 - rmse: 0.3464
# Epoch 38: val_loss improved from 0.17001 to 0.16994, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1450 - mae: 0.2990 - rmse: 0.3807 - val_loss: 0.1699 - val_mae: 0.3229 - val_rmse: 0.4122 - learning_rate: 0.0010
# Epoch 39/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1102 - mae: 0.2630 - rmse: 0.3314
# Epoch 39: val_loss did not improve from 0.16994
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1347 - mae: 0.2933 - rmse: 0.3670 - val_loss: 0.1769 - val_mae: 0.3436 - val_rmse: 0.4206 - learning_rate: 0.0010
# Epoch 40/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1555 - mae: 0.3134 - rmse: 0.3927
# Epoch 40: val_loss improved from 0.16994 to 0.16778, saving model to ./logs/best_model.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1626 - mae: 0.3223 - rmse: 0.4033 - val_loss: 0.1678 - val_mae: 0.3265 - val_rmse: 0.4096 - learning_rate: 0.0010
# Epoch 41/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1689 - mae: 0.3381 - rmse: 0.4085
# Epoch 41: val_loss did not improve from 0.16778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1606 - mae: 0.3195 - rmse: 0.4008 - val_loss: 0.1679 - val_mae: 0.3274 - val_rmse: 0.4097 - learning_rate: 0.0010
# Epoch 42/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1154 - mae: 0.2685 - rmse: 0.3390
# Epoch 42: val_loss did not improve from 0.16778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1547 - mae: 0.3073 - rmse: 0.3933 - val_loss: 0.1851 - val_mae: 0.3511 - val_rmse: 0.4303 - learning_rate: 0.0010
# Epoch 43/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1429 - mae: 0.2981 - rmse: 0.3766
# Epoch 43: val_loss did not improve from 0.16778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1931 - mae: 0.3416 - rmse: 0.4394 - val_loss: 0.3428 - val_mae: 0.4665 - val_rmse: 0.5855 - learning_rate: 0.0010
# Epoch 44/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1782 - mae: 0.3248 - rmse: 0.4214
# Epoch 44: val_loss did not improve from 0.16778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1799 - mae: 0.3342 - rmse: 0.4241 - val_loss: 0.2033 - val_mae: 0.3545 - val_rmse: 0.4509 - learning_rate: 0.0010
# Epoch 45/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1213 - mae: 0.2842 - rmse: 0.3479
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 45: val_loss did not improve from 0.16778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1440 - mae: 0.3020 - rmse: 0.3795 - val_loss: 0.1830 - val_mae: 0.3309 - val_rmse: 0.4278 - learning_rate: 0.0010
# Epoch 46/500
# 15/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1259 - mae: 0.2623 - rmse: 0.3540
# Epoch 46: val_loss did not improve from 0.16778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1478 - mae: 0.2952 - rmse: 0.3845 - val_loss: 0.1707 - val_mae: 0.3251 - val_rmse: 0.4132 - learning_rate: 2.0000e-04
# Epoch 47/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1065 - mae: 0.2566 - rmse: 0.3259
# Epoch 47: val_loss did not improve from 0.16778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1308 - mae: 0.2838 - rmse: 0.3616 - val_loss: 0.1812 - val_mae: 0.3371 - val_rmse: 0.4257 - learning_rate: 2.0000e-04
# Epoch 48/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1078 - mae: 0.2579 - rmse: 0.3279
# Epoch 48: val_loss did not improve from 0.16778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1398 - mae: 0.2952 - rmse: 0.3739 - val_loss: 0.1781 - val_mae: 0.3338 - val_rmse: 0.4220 - learning_rate: 2.0000e-04
# Epoch 49/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0947 - mae: 0.2494 - rmse: 0.3074
# Epoch 49: val_loss did not improve from 0.16778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1269 - mae: 0.2864 - rmse: 0.3563 - val_loss: 0.1746 - val_mae: 0.3282 - val_rmse: 0.4179 - learning_rate: 2.0000e-04
# Epoch 50/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0949 - mae: 0.2435 - rmse: 0.3070
# Epoch 50: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 50: val_loss did not improve from 0.16778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1321 - mae: 0.2913 - rmse: 0.3635 - val_loss: 0.1737 - val_mae: 0.3250 - val_rmse: 0.4168 - learning_rate: 2.0000e-04
# Epoch 51/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0944 - mae: 0.2465 - rmse: 0.3066
# Epoch 51: val_loss did not improve from 0.16778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1336 - mae: 0.2874 - rmse: 0.3654 - val_loss: 0.1731 - val_mae: 0.3244 - val_rmse: 0.4160 - learning_rate: 4.0000e-05
# Epoch 52/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0977 - mae: 0.2495 - rmse: 0.3118
# Epoch 52: val_loss did not improve from 0.16778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1238 - mae: 0.2837 - rmse: 0.3518 - val_loss: 0.1723 - val_mae: 0.3240 - val_rmse: 0.4151 - learning_rate: 4.0000e-05
# Epoch 53/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1055 - mae: 0.2612 - rmse: 0.3247
# Epoch 53: val_loss did not improve from 0.16778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1231 - mae: 0.2817 - rmse: 0.3508 - val_loss: 0.1720 - val_mae: 0.3239 - val_rmse: 0.4147 - learning_rate: 4.0000e-05
# Epoch 54/500
# 15/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0924 - mae: 0.2316 - rmse: 0.3033
# Epoch 54: val_loss did not improve from 0.16778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1247 - mae: 0.2715 - rmse: 0.3531 - val_loss: 0.1721 - val_mae: 0.3243 - val_rmse: 0.4149 - learning_rate: 4.0000e-05
# Epoch 55/500
# 14/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0868 - mae: 0.2316 - rmse: 0.2938
# Epoch 55: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 55: val_loss did not improve from 0.16778
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1233 - mae: 0.2734 - rmse: 0.3511 - val_loss: 0.1726 - val_mae: 0.3250 - val_rmse: 0.4154 - learning_rate: 4.0000e-05
# Epoch 55: early stopping
# Restoring model weights from the end of the best epoch: 40.
# Keras training complete.
# CPU times: user 9.25 s, sys: 818 ms, total: 10.1 s
# Wall time: 9.13 s

# %%
# %load_ext tensorboard
# %tensorboard --logdir=./logs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 33459), started 1:14:20 ago. (Use '!kill 33459' to kill it.)
#       <iframe id="tensorboard-frame-e465e150bd9c66b3" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e465e150bd9c66b3");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

def plot_forecast(model, x_test, y_test, test_index, history, preprocessor_instance):
    """
    Plots training loss and actual vs forecasted values for Keras model.

    Args:
        model (keras.Model): Trained Keras model.
        x_test (np.ndarray): Scaled test features.
        y_test (np.ndarray): Scaled test target.
        test_index (pd.Index): Datetime index for the test set.
        history (keras.callbacks.History): Training history object.
        preprocessor_instance (TimeSeriesStandardScaler): 
                The fitted preprocessor object used for inverse scaling.
    """
    fig, ax = plt.subplots(2, 1, figsize=(14, 10))

    # Plot 1: Training and Validation Loss
    # Training loss plot
    pd.Series(history.history['loss']).plot(
                       style='k--',
                       alpha=0.50, 
                       title='Keras Model Loss per Epoch',
                       ax = ax[0], 
                       label='Training loss')
    
    # Validation loss plot
    pd.Series(history.history['val_loss']).plot(
                      style='k',
                      ax=ax[0],
                      label='Validation loss')
    ax[0].legend()
    ax[0].grid(True, linestyle='--', alpha=0.5)

    
    # Plot 2: Actual vs Predicted Values
    # Get predictions
    predicted = model.predict(x_test)
    # Inverse transform predictions and actual values to original scale
    predicted_original = preprocessor_instance.inverse_transform_target(predicted)
    y_test_original = preprocessor_instance.inverse_transform_target(y_test)

    # Plot actual values
    pd.Series(y_test_original.reshape(-1), 
              index=test_index).plot(
                                style='k--', 
                                alpha=0.5, 
                                ax=ax[1], 
                                title='Keras LSTM One-Step Forecast vs Actual (Test Set)',
                                label='Actual')
    pd.Series(predicted_original.reshape(-1), 
              index=test_index).plot(
                                style='k',
                                label='Forecast', 
                                ax=ax[1])
    fig.tight_layout()
    ax[1].legend()
    ax[1].grid(True, linestyle='--', alpha=0.5)
    ax[1].set_xlabel('Month')
    ax[1].set_ylabel('Energy Consumption')
    plt.show()

    mae_keras = mean_absolute_error(y_test_original, predicted_original)
    rmse_keras = np.sqrt(mean_squared_error(y_test_original, predicted_original))
    print(f"Keras Test Set MAE:  {mae_keras:.4f}") 
    print(f"Keras Test Set RMSE: {rmse_keras:.4f}")

# %%
history_lstm_keras.history.keys()
# Out:
# dict_keys(['loss', 'mae', 'rmse', 'val_loss', 'val_mae', 'val_rmse', 'learning_rate'])

# %%
plot_forecast(keras_lstm_model, 
              x_test_k, 
              y_test_k, 
              k_test_scaled.index, 
              history_lstm_keras, scaler)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Keras Test Set MAE:  151.8853
# Keras Test Set RMSE: 177.5005

# %% [markdown]
# ## Using Darts RNNModel for LSTM

# %%
import darts
darts.__version__
# Out:
# '0.38.0'

# %%
from darts.models import RNNModel
from darts import TimeSeries
from darts.dataprocessing.transformers import Scaler
from darts.metrics import rmse, mae
import pytorch_lightning as pl
from pytorch_lightning.callbacks import EarlyStopping
import torch

# %%
en_cp = en_df.copy().reset_index()
ts = TimeSeries.from_dataframe(en_cp, 
                               time_col='Month', 
                               value_cols='y', 
                               freq='MS')
ts = ts.astype(np.float32)

# %%
n_total = len(ts)
n_test = 12 
n_val = 36 

# Calculate split indices
test_start = n_total - n_test
val_start = test_start - n_val
        
# Create splits maintaining temporal order
d_train = ts[:val_start]
d_val = ts[val_start:test_start]
d_test = ts[test_start:]

print(f'''
train: {len(d_train)}
val : {len(d_val)}
test: {len(d_test)}''')
# Out:
# train: 540
# val : 36
# test: 12

# %%
from sklearn.preprocessing import StandardScaler
d_scaler = Scaler(StandardScaler())

d_train_scaled = d_scaler.fit_transform(d_train)
d_val_scaled = d_scaler.transform(d_val)
d_test_scaled = d_scaler.transform(d_test)
d_series = d_scaler.transform(ts)

# %%
# Darts LSTM parameters
darts_lstm_params = {
    'model':'LSTM',            # Specify the RNN type
    'input_chunk_length': 12,  # How many time steps the model sees (your 'window'),
    'training_length': 13,
    'hidden_dim': 32,  # LSTM units
    'n_rnn_layers': 2, # Number of LSTM layers
    'dropout': 0.2,    # Dropout rate
    'batch_size': 32,  # Batch size for training
    'n_epochs': 500,   # Max number of epochs
    'optimizer_kwargs': {'lr': 0.001}, # Adam is default
    'random_state': 42, # For reproducibility
    'force_reset':True  # Ensure fresh model training
}

PATIENCE=15
early_stopper = EarlyStopping(
    monitor="val_loss",  # Darts/PyTorch Lightning default validation loss metric name
    patience=PATIENCE,   # Early stopping patience
    min_delta=0.001,     # Minimum change to qualify as an improvement
    mode='min',          # We want to minimize loss
    verbose=True)

trainer_kwargs = {
    "callbacks": [early_stopper],
    "enable_progress_bar": True, # Show training progress bar
    "accelerator":"auto"}

lr_scheduler_kwargs = {
        "mode": "min",
        "monitor": "val_loss",
        "factor": 0.2,
        "patience": PATIENCE//3, 
        "min_lr": 1e-6
    }

darts_lstm_model = RNNModel(
    **darts_lstm_params,
    model_name='energy_lstm',
    log_tensorboard=True,       # Set True to use TensorBoard
    save_checkpoints=True,      # Set True to save model checkpoints
    lr_scheduler_cls=torch.optim.lr_scheduler.ReduceLROnPlateau,
    lr_scheduler_kwargs= lr_scheduler_kwargs,
    pl_trainer_kwargs=trainer_kwargs # Pass trainer args including callbacks
)

# %%
# %%time
darts_lstm_model.fit(d_train_scaled,
                     val_series=d_val_scaled,
                     verbose=True) # verbose=True shows epoch progress
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name            | Type             | Params | Mode
# -------------------------------------------------------------
# 0 | criterion       | MSELoss          | 0      | train
# 1 | train_criterion | MSELoss          | 0      | train
# 2 | val_criterion   | MSELoss          | 0      | train
# 3 | train_metrics   | MetricCollection | 0      | train
# 4 | val_metrics     | MetricCollection | 0      | train
# 5 | rnn             | LSTM             | 12.9 K | train
# 6 | V               | Linear           | 33     | train
# -------------------------------------------------------------
# 13.0 K    Trainable params
# 0         Non-trainable params
# 13.0 K    Total params
# 0.052     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████| 17/17 [00:03<00:00,  5.41it/s, v_num=logs, train_loss=0.930, val_loss=0.959]
# Metric val_loss improved. New best score: 0.959
# Epoch 1: 100%|██████████| 17/17 [00:00<00:00, 126.67it/s, v_num=logs, train_loss=0.881, val_loss=0.943]
# Metric val_loss improved by 0.016 >= min_delta = 0.001. New best score: 0.943
# Epoch 2: 100%|██████████| 17/17 [00:00<00:00, 121.98it/s, v_num=logs, train_loss=0.587, val_loss=0.858]
# Metric val_loss improved by 0.085 >= min_delta = 0.001. New best score: 0.858
# Epoch 3: 100%|██████████| 17/17 [00:00<00:00, 122.72it/s, v_num=logs, train_loss=0.374, val_loss=0.720]
# Metric val_loss improved by 0.138 >= min_delta = 0.001. New best score: 0.720
# Epoch 4: 100%|██████████| 17/17 [00:00<00:00, 125.93it/s, v_num=logs, train_loss=0.364, val_loss=0.593]
# Metric val_loss improved by 0.127 >= min_delta = 0.001. New best score: 0.593
# Epoch 5: 100%|██████████| 17/17 [00:00<00:00, 124.77it/s, v_num=logs, train_loss=0.413, val_loss=0.578]
# Metric val_loss improved by 0.016 >= min_delta = 0.001. New best score: 0.578
# Epoch 6: 100%|██████████| 17/17 [00:00<00:00, 127.25it/s, v_num=logs, train_loss=0.280, val_loss=0.565]
# Metric val_loss improved by 0.013 >= min_delta = 0.001. New best score: 0.565
# Epoch 7: 100%|██████████| 17/17 [00:00<00:00, 128.46it/s, v_num=logs, train_loss=0.334, val_loss=0.551]
# Metric val_loss improved by 0.014 >= min_delta = 0.001. New best score: 0.551
# Epoch 9: 100%|██████████| 17/17 [00:00<00:00, 126.22it/s, v_num=logs, train_loss=0.302, val_loss=0.541]
# Metric val_loss improved by 0.010 >= min_delta = 0.001. New best score: 0.541
# Epoch 10: 100%|██████████| 17/17 [00:00<00:00, 121.85it/s, v_num=logs, train_loss=0.263, val_loss=0.516]
# Metric val_loss improved by 0.025 >= min_delta = 0.001. New best score: 0.516
# Epoch 14: 100%|██████████| 17/17 [00:00<00:00, 58.82it/s, v_num=logs, train_loss=0.217, val_loss=0.514]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.514
# Epoch 15: 100%|██████████| 17/17 [00:00<00:00, 98.64it/s, v_num=logs, train_loss=0.178, val_loss=0.501]
# Metric val_loss improved by 0.013 >= min_delta = 0.001. New best score: 0.501
# Epoch 20: 100%|██████████| 17/17 [00:00<00:00, 108.88it/s, v_num=logs, train_loss=0.172, val_loss=0.488]
# Metric val_loss improved by 0.013 >= min_delta = 0.001. New best score: 0.488
# Epoch 21: 100%|██████████| 17/17 [00:00<00:00, 97.80it/s, v_num=logs, train_loss=0.155, val_loss=0.476]
# Metric val_loss improved by 0.012 >= min_delta = 0.001. New best score: 0.476
# Epoch 22: 100%|██████████| 17/17 [00:00<00:00, 121.78it/s, v_num=logs, train_loss=0.190, val_loss=0.470]
# Metric val_loss improved by 0.006 >= min_delta = 0.001. New best score: 0.470
# Epoch 23: 100%|██████████| 17/17 [00:00<00:00, 120.76it/s, v_num=logs, train_loss=0.145, val_loss=0.459]
# Metric val_loss improved by 0.011 >= min_delta = 0.001. New best score: 0.459
# Epoch 28: 100%|██████████| 17/17 [00:00<00:00, 92.99it/s, v_num=logs, train_loss=0.120, val_loss=0.456]
# Metric val_loss improved by 0.003 >= min_delta = 0.001. New best score: 0.456
# Epoch 31: 100%|██████████| 17/17 [00:00<00:00, 111.64it/s, v_num=logs, train_loss=0.164, val_loss=0.446]
# Metric val_loss improved by 0.010 >= min_delta = 0.001. New best score: 0.446
# Epoch 32: 100%|██████████| 17/17 [00:00<00:00, 113.56it/s, v_num=logs, train_loss=0.153, val_loss=0.445]
# Metric val_loss improved by 0.001 >= min_delta = 0.001. New best score: 0.445
# Epoch 33: 100%|██████████| 17/17 [00:00<00:00, 113.04it/s, v_num=logs, train_loss=0.159, val_loss=0.438]
# Metric val_loss improved by 0.007 >= min_delta = 0.001. New best score: 0.438
# Epoch 34: 100%|██████████| 17/17 [00:00<00:00, 115.04it/s, v_num=logs, train_loss=0.132, val_loss=0.426]
# Metric val_loss improved by 0.013 >= min_delta = 0.001. New best score: 0.426
# Epoch 35: 100%|██████████| 17/17 [00:00<00:00, 104.00it/s, v_num=logs, train_loss=0.144, val_loss=0.417]
# Metric val_loss improved by 0.009 >= min_delta = 0.001. New best score: 0.417
# Epoch 37: 100%|██████████| 17/17 [00:00<00:00, 25.20it/s, v_num=logs, train_loss=0.154, val_loss=0.408]
# Metric val_loss improved by 0.008 >= min_delta = 0.001. New best score: 0.408
# Epoch 41: 100%|██████████| 17/17 [00:00<00:00, 111.22it/s, v_num=logs, train_loss=0.121, val_loss=0.389]
# Metric val_loss improved by 0.019 >= min_delta = 0.001. New best score: 0.389
# Epoch 42: 100%|██████████| 17/17 [00:00<00:00, 47.62it/s, v_num=logs, train_loss=0.125, val_loss=0.378]
# Metric val_loss improved by 0.012 >= min_delta = 0.001. New best score: 0.378
# Epoch 45: 100%|██████████| 17/17 [00:00<00:00, 102.72it/s, v_num=logs, train_loss=0.165, val_loss=0.370]
# Metric val_loss improved by 0.008 >= min_delta = 0.001. New best score: 0.370
# Epoch 48: 100%|██████████| 17/17 [00:00<00:00, 79.67it/s, v_num=logs, train_loss=0.156, val_loss=0.358]
# Metric val_loss improved by 0.011 >= min_delta = 0.001. New best score: 0.358
# Epoch 50: 100%|██████████| 17/17 [00:00<00:00, 106.15it/s, v_num=logs, train_loss=0.114, val_loss=0.344]
# Metric val_loss improved by 0.014 >= min_delta = 0.001. New best score: 0.344
# Epoch 55: 100%|██████████| 17/17 [00:00<00:00, 120.93it/s, v_num=logs, train_loss=0.137, val_loss=0.318]
# Metric val_loss improved by 0.026 >= min_delta = 0.001. New best score: 0.318
# Epoch 61: 100%|██████████| 17/17 [00:00<00:00, 126.22it/s, v_num=logs, train_loss=0.122, val_loss=0.305]
# Metric val_loss improved by 0.013 >= min_delta = 0.001. New best score: 0.305
# Epoch 62: 100%|██████████| 17/17 [00:00<00:00, 125.87it/s, v_num=logs, train_loss=0.123, val_loss=0.301]
# Metric val_loss improved by 0.004 >= min_delta = 0.001. New best score: 0.301
# Epoch 63: 100%|██████████| 17/17 [00:00<00:00, 124.38it/s, v_num=logs, train_loss=0.134, val_loss=0.293]
# Metric val_loss improved by 0.008 >= min_delta = 0.001. New best score: 0.293
# Epoch 68: 100%|██████████| 17/17 [00:00<00:00, 124.27it/s, v_num=logs, train_loss=0.136, val_loss=0.284]
# Metric val_loss improved by 0.009 >= min_delta = 0.001. New best score: 0.284
# Epoch 69: 100%|██████████| 17/17 [00:00<00:00, 118.92it/s, v_num=logs, train_loss=0.116, val_loss=0.281]
# Metric val_loss improved by 0.003 >= min_delta = 0.001. New best score: 0.281
# Epoch 72: 100%|██████████| 17/17 [00:00<00:00, 124.65it/s, v_num=logs, train_loss=0.108, val_loss=0.268]
# Metric val_loss improved by 0.013 >= min_delta = 0.001. New best score: 0.268
# Epoch 75: 100%|██████████| 17/17 [00:00<00:00, 121.36it/s, v_num=logs, train_loss=0.127, val_loss=0.258]
# Metric val_loss improved by 0.010 >= min_delta = 0.001. New best score: 0.258
# Epoch 78: 100%|██████████| 17/17 [00:00<00:00, 103.39it/s, v_num=logs, train_loss=0.097, val_loss=0.252]
# Metric val_loss improved by 0.006 >= min_delta = 0.001. New best score: 0.252
# Epoch 79: 100%|██████████| 17/17 [00:00<00:00, 111.45it/s, v_num=logs, train_loss=0.125, val_loss=0.241]
# Metric val_loss improved by 0.011 >= min_delta = 0.001. New best score: 0.241
# Epoch 85: 100%|██████████| 17/17 [00:00<00:00, 119.74it/s, v_num=logs, train_loss=0.104, val_loss=0.236]
# Metric val_loss improved by 0.004 >= min_delta = 0.001. New best score: 0.236
# Epoch 89: 100%|██████████| 17/17 [00:00<00:00, 119.67it/s, v_num=logs, train_loss=0.0835, val_loss=0.231]
# Metric val_loss improved by 0.005 >= min_delta = 0.001. New best score: 0.231
# Epoch 90: 100%|██████████| 17/17 [00:00<00:00, 117.51it/s, v_num=logs, train_loss=0.127, val_loss=0.226]
# Metric val_loss improved by 0.005 >= min_delta = 0.001. New best score: 0.226
# Epoch 93: 100%|██████████| 17/17 [00:00<00:00, 113.57it/s, v_num=logs, train_loss=0.142, val_loss=0.224]
# Metric val_loss improved by 0.003 >= min_delta = 0.001. New best score: 0.224
# Epoch 94: 100%|██████████| 17/17 [00:00<00:00, 113.40it/s, v_num=logs, train_loss=0.0908, val_loss=0.222]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.222
# Epoch 95: 100%|██████████| 17/17 [00:00<00:00, 112.78it/s, v_num=logs, train_loss=0.140, val_loss=0.219]
# Metric val_loss improved by 0.003 >= min_delta = 0.001. New best score: 0.219
# Epoch 97: 100%|██████████| 17/17 [00:00<00:00, 114.47it/s, v_num=logs, train_loss=0.113, val_loss=0.218]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.218
# Epoch 99: 100%|██████████| 17/17 [00:00<00:00, 117.60it/s, v_num=logs, train_loss=0.0951, val_loss=0.215]
# Metric val_loss improved by 0.003 >= min_delta = 0.001. New best score: 0.215
# Epoch 101: 100%|██████████| 17/17 [00:00<00:00, 118.27it/s, v_num=logs, train_loss=0.109, val_loss=0.205]
# Metric val_loss improved by 0.010 >= min_delta = 0.001. New best score: 0.205
# Epoch 104: 100%|██████████| 17/17 [00:00<00:00, 117.70it/s, v_num=logs, train_loss=0.126, val_loss=0.199]
# Metric val_loss improved by 0.006 >= min_delta = 0.001. New best score: 0.199
# Epoch 119: 100%|██████████| 17/17 [00:00<00:00, 122.27it/s, v_num=logs, train_loss=0.100, val_loss=0.204]
# Monitored metric val_loss did not improve in the last 15 records. Best score: 0.199. Signaling Trainer to stop.
# Epoch 119: 100%|██████████| 17/17 [00:00<00:00, 110.28it/s, v_num=logs, train_loss=0.100, val_loss=0.204]
# CPU times: user 14.7 s, sys: 3.78 s, total: 18.5 s
# Wall time: 26.6 s
# RNNModel(model=LSTM, hidden_dim=32, n_rnn_layers=2, dropout=0.2, training_length=13, input_chunk_length=12, batch_size=32, n_epochs=500, optimizer_kwargs={'lr': 0.001}, random_state=42, force_reset=True, model_name=energy_lstm, log_tensorboard=True, save_checkpoints=True, lr_scheduler_cls=<class 'torch.optim.lr_scheduler.ReduceLROnPlateau'>, lr_scheduler_kwargs={'mode': 'min', 'monitor': 'val_loss', 'factor': 0.2, 'patience': 5, 'min_lr': 1e-06}, pl_trainer_kwargs={'callbacks': [<pytorch_lightning.callbacks.early_stopping.EarlyStopping object at 0x320d6b9d0>], 'enable_progress_bar': True, 'accelerator': 'auto'})

# %%
# %load_ext tensorboard
# %tensorboard --logdir=darts_logs/
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6007 (pid 38872), started 0:00:48 ago. (Use '!kill 38872' to kill it.)
#       <iframe id="tensorboard-frame-6c031199972a8469" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6c031199972a8469");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
best_darts_model = darts_lstm_model.load_from_checkpoint(
                               model_name="energy_lstm", 
                               best=True)
best_darts_model
# Out:
# RNNModel(model=LSTM, hidden_dim=32, n_rnn_layers=2, dropout=0.2, training_length=13, input_chunk_length=12, batch_size=32, n_epochs=500, optimizer_kwargs={'lr': 0.001}, random_state=42, force_reset=True, model_name=energy_lstm, log_tensorboard=True, save_checkpoints=True, lr_scheduler_cls=<class 'torch.optim.lr_scheduler.ReduceLROnPlateau'>, lr_scheduler_kwargs={'mode': 'min', 'monitor': 'val_loss', 'factor': 0.2, 'patience': 5, 'min_lr': 1e-06}, pl_trainer_kwargs={'callbacks': [<pytorch_lightning.callbacks.early_stopping.EarlyStopping object at 0x321334590>], 'enable_progress_bar': True, 'accelerator': 'auto'})

# %% [markdown]
# ### One-Step Forecast (Similar to Keras)

# %%
one_step_forecast_scaled= darts_lstm_model.historical_forecasts(
    series=d_series,
    start=d_test_scaled.start_time(),
    forecast_horizon=1, # We only want one-step-ahead predictions
    stride=1,           # Move one step at a time
    retrain=False,      # Do not retrain the model at each step
    verbose=True
)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  3.02it/s]

# %%
one_step_forecast = d_scaler.inverse_transform(one_step_forecast_scaled)

# %%
plt.figure(figsize=(16, 5))
d_test.plot(label='Actual', linestyle='--', alpha=0.65) # Plot full historical data
one_step_forecast.plot(label='Forecast', color='k', alpha=0.65)
plt.title('Darts LSTM One-Step Forecast vs Actuals')
plt.xlabel('Month')
plt.ylabel('Energy Consumption')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
rmse_val = rmse(d_test, one_step_forecast)
mae_val = mae(d_test, one_step_forecast)
print(f"Darts Test Set MAE:  {mae_val:.4f}")
print(f"Darts Test Set RMSE: {rmse_val:.4f}")
# Out:
# Darts Test Set MAE:  73.4404
# Darts Test Set RMSE: 126.9493

# %% [markdown]
# ### Darts Recursive Forecast

# %%
d_train_val_scaled = d_train_scaled.append(d_val_scaled)
preds_scaled = best_darts_model.predict(n=len(d_test), 
                                  series=d_train_val_scaled)

preds_inv = d_scaler.inverse_transform(preds_scaled)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:01<00:00,  0.75it/s]

# %%
plt.figure(figsize=(16, 5))
d_test.plot(label='Actual', linestyle='--', alpha=0.65) # Plot full historical data
preds_inv.plot(label='Forecast', color='k', alpha=0.65)
plt.title('Darts LSTM Recursive Forecast vs Actuals')
plt.xlabel('Month')
plt.ylabel('Energy Consumption')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
rmse_val = rmse(d_test, preds_inv)
mae_val = mae(d_test, preds_inv)
print(f"Darts Test Set MAE:  {mae_val:.4f}")
print(f"Darts Test Set RMSE: {rmse_val:.4f}")
# Out:
# Darts Test Set MAE:  115.5418
# Darts Test Set RMSE: 161.0847

# %% [markdown]
# ## Using Darts BlockRNNModel: Long-Term Multioutput

# %%
from darts.models import BlockRNNModel

# %%
# Darts Block LSTM parameters
darts_blocklstm_params = {
    'model':'LSTM',            # Specify the RNN type
    'input_chunk_length': 24,  # How many time steps the model sees (your 'window')
    'output_chunk_length': 12,  # How many steps the model predicts forward at a time
    'hidden_dim': 32,  # LSTM units
    'n_rnn_layers': 2, # Number of LSTM layers
    'dropout': 0.2,    # Dropout rate
    'batch_size': 32,  # Batch size for training
    'n_epochs': 500,   # Max number of epochs
    'optimizer_kwargs': {'lr': 0.001}, # Adam is default
    'random_state': 42, # For reproducibility
    'force_reset':True  # Ensure fresh model training
}

PATIENCE=15
early_stopper = EarlyStopping(
    monitor="val_loss",  # Darts/PyTorch Lightning default validation loss metric name
    patience=PATIENCE,   # Early stopping patience
    min_delta=0.001,     # Minimum change to qualify as an improvement
    mode='min',          # We want to minimize loss
    verbose=True)

trainer_kwargs = {
    "callbacks": [early_stopper],
    "enable_progress_bar": True, # Show training progress bar
    "accelerator":"auto"}

lr_scheduler_kwargs = {
        "mode": "min",
        "monitor": "val_loss",
        "factor": 0.2,
        "patience": PATIENCE//3, 
        "min_lr": 1e-6
    }

# %%
darts_blocklstm_model = BlockRNNModel(
    **darts_blocklstm_params,
    model_name='energy_blocklstm',
    # log_tensorboard=True,       # Set True to use TensorBoard
    save_checkpoints=True,      # Set True to save model checkpoints
    lr_scheduler_cls=torch.optim.lr_scheduler.ReduceLROnPlateau,
    lr_scheduler_kwargs= lr_scheduler_kwargs,
    pl_trainer_kwargs=trainer_kwargs # Pass trainer args including callbacks
)

# %%
# %%time
darts_blocklstm_model.fit(d_train_scaled,
                     val_series=d_val_scaled,
                     verbose=True) # verbose=True shows epoch progress
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name            | Type             | Params | Mode
# -------------------------------------------------------------
# 0 | criterion       | MSELoss          | 0      | train
# 1 | train_criterion | MSELoss          | 0      | train
# 2 | val_criterion   | MSELoss          | 0      | train
# 3 | train_metrics   | MetricCollection | 0      | train
# 4 | val_metrics     | MetricCollection | 0      | train
# 5 | rnn             | LSTM             | 12.9 K | train
# 6 | fc              | Sequential       | 33     | train
# -------------------------------------------------------------
# 13.0 K    Trainable params
# 0         Non-trainable params
# 13.0 K    Total params
# 0.052     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Epoch 0: 100%|██████████| 16/16 [00:00<00:00, 16.05it/s, train_loss=0.778, val_loss=0.723]
# Metric val_loss improved. New best score: 0.723
# Epoch 1: 100%|██████████| 16/16 [00:00<00:00, 86.84it/s, train_loss=0.571, val_loss=0.680]
# Metric val_loss improved by 0.044 >= min_delta = 0.001. New best score: 0.680
# Epoch 2: 100%|██████████| 16/16 [00:00<00:00, 98.75it/s, train_loss=0.371, val_loss=0.562]
# Metric val_loss improved by 0.118 >= min_delta = 0.001. New best score: 0.562
# Epoch 3: 100%|██████████| 16/16 [00:00<00:00, 97.81it/s, train_loss=0.172, val_loss=0.395]
# Metric val_loss improved by 0.167 >= min_delta = 0.001. New best score: 0.395
# Epoch 4: 100%|██████████| 16/16 [00:00<00:00, 92.76it/s, train_loss=0.168, val_loss=0.308]
# Metric val_loss improved by 0.088 >= min_delta = 0.001. New best score: 0.308
# Epoch 5: 100%|██████████| 16/16 [00:00<00:00, 99.00it/s, train_loss=0.164, val_loss=0.272]
# Metric val_loss improved by 0.035 >= min_delta = 0.001. New best score: 0.272
# Epoch 6: 100%|██████████| 16/16 [00:00<00:00, 87.13it/s, train_loss=0.127, val_loss=0.255]
# Metric val_loss improved by 0.018 >= min_delta = 0.001. New best score: 0.255
# Epoch 7: 100%|██████████| 16/16 [00:00<00:00, 98.51it/s, train_loss=0.173, val_loss=0.238]
# Metric val_loss improved by 0.016 >= min_delta = 0.001. New best score: 0.238
# Epoch 8: 100%|██████████| 16/16 [00:00<00:00, 99.39it/s, train_loss=0.173, val_loss=0.232]
# Metric val_loss improved by 0.007 >= min_delta = 0.001. New best score: 0.232
# Epoch 9: 100%|██████████| 16/16 [00:00<00:00, 98.40it/s, train_loss=0.131, val_loss=0.225]
# Metric val_loss improved by 0.006 >= min_delta = 0.001. New best score: 0.225
# Epoch 10: 100%|██████████| 16/16 [00:00<00:00, 98.46it/s, train_loss=0.139, val_loss=0.218]
# Metric val_loss improved by 0.007 >= min_delta = 0.001. New best score: 0.218
# Epoch 11: 100%|██████████| 16/16 [00:00<00:00, 98.72it/s, train_loss=0.120, val_loss=0.216]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.216
# Epoch 12: 100%|██████████| 16/16 [00:00<00:00, 98.76it/s, train_loss=0.118, val_loss=0.207]
# Metric val_loss improved by 0.009 >= min_delta = 0.001. New best score: 0.207
# Epoch 16: 100%|██████████| 16/16 [00:00<00:00, 97.08it/s, train_loss=0.101, val_loss=0.203]
# Metric val_loss improved by 0.004 >= min_delta = 0.001. New best score: 0.203
# Epoch 17: 100%|██████████| 16/16 [00:00<00:00, 95.93it/s, train_loss=0.0991, val_loss=0.196]
# Metric val_loss improved by 0.008 >= min_delta = 0.001. New best score: 0.196
# Epoch 19: 100%|██████████| 16/16 [00:00<00:00, 98.87it/s, train_loss=0.0996, val_loss=0.188]
# Metric val_loss improved by 0.007 >= min_delta = 0.001. New best score: 0.188
# Epoch 20: 100%|██████████| 16/16 [00:00<00:00, 88.77it/s, train_loss=0.102, val_loss=0.180]
# Metric val_loss improved by 0.009 >= min_delta = 0.001. New best score: 0.180
# Epoch 22: 100%|██████████| 16/16 [00:00<00:00, 99.35it/s, train_loss=0.100, val_loss=0.170]
# Metric val_loss improved by 0.010 >= min_delta = 0.001. New best score: 0.170
# Epoch 23: 100%|██████████| 16/16 [00:00<00:00, 99.38it/s, train_loss=0.0976, val_loss=0.159]
# Metric val_loss improved by 0.011 >= min_delta = 0.001. New best score: 0.159
# Epoch 24: 100%|██████████| 16/16 [00:00<00:00, 98.61it/s, train_loss=0.103, val_loss=0.146]
# Metric val_loss improved by 0.013 >= min_delta = 0.001. New best score: 0.146
# Epoch 26: 100%|██████████| 16/16 [00:00<00:00, 99.90it/s, train_loss=0.086, val_loss=0.140]
# Metric val_loss improved by 0.006 >= min_delta = 0.001. New best score: 0.140
# Epoch 27: 100%|██████████| 16/16 [00:00<00:00, 96.46it/s, train_loss=0.101, val_loss=0.138]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.138
# Epoch 28: 100%|██████████| 16/16 [00:00<00:00, 99.42it/s, train_loss=0.101, val_loss=0.134]
# Metric val_loss improved by 0.004 >= min_delta = 0.001. New best score: 0.134
# Epoch 30: 100%|██████████| 16/16 [00:00<00:00, 96.67it/s, train_loss=0.0855, val_loss=0.126]
# Metric val_loss improved by 0.007 >= min_delta = 0.001. New best score: 0.126
# Epoch 32: 100%|██████████| 16/16 [00:00<00:00, 96.46it/s, train_loss=0.094, val_loss=0.122]
# Metric val_loss improved by 0.005 >= min_delta = 0.001. New best score: 0.122
# Epoch 47: 100%|██████████| 16/16 [00:00<00:00, 94.46it/s, train_loss=0.0632, val_loss=0.123]
# Monitored metric val_loss did not improve in the last 15 records. Best score: 0.122. Signaling Trainer to stop.
# Epoch 47: 100%|██████████| 16/16 [00:00<00:00, 87.53it/s, train_loss=0.0632, val_loss=0.123]
# CPU times: user 5.8 s, sys: 1.4 s, total: 7.2 s
# Wall time: 9.99 s
# BlockRNNModel(output_chunk_shift=0, model=LSTM, hidden_dim=32, n_rnn_layers=2, hidden_fc_sizes=None, dropout=0.2, activation=ReLU, use_static_covariates=True, input_chunk_length=24, output_chunk_length=12, batch_size=32, n_epochs=500, optimizer_kwargs={'lr': 0.001}, random_state=42, force_reset=True, model_name=energy_blocklstm, save_checkpoints=True, lr_scheduler_cls=<class 'torch.optim.lr_scheduler.ReduceLROnPlateau'>, lr_scheduler_kwargs={'mode': 'min', 'monitor': 'val_loss', 'factor': 0.2, 'patience': 5, 'min_lr': 1e-06}, pl_trainer_kwargs={'callbacks': [<pytorch_lightning.callbacks.early_stopping.EarlyStopping object at 0x3246801d0>], 'enable_progress_bar': True, 'accelerator': 'auto'})

# %%
best_block_model = darts_blocklstm_model.load_from_checkpoint(
                               model_name="energy_blocklstm", 
                               best=True)

# %%
d_train_val_scaled = d_train_scaled.append(d_val_scaled)
block_preds_scaled = best_block_model.predict(n=len(d_test), 
                                  series=d_train_val_scaled)
block_preds_inv = d_scaler.inverse_transform(block_preds_scaled)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 101.05it/s]

# %%
rmse_val = rmse(d_test, block_preds_inv)
mae_val = mae(d_test, block_preds_inv)
print(f"Darts Test Set MAE:  {mae_val:.4f}")
print(f"Darts Test Set RMSE: {rmse_val:.4f}")
# Out:
# Darts Test Set MAE:  137.6819
# Darts Test Set RMSE: 183.7500

# %%
plt.figure(figsize=(16, 5))
d_test.plot(label='Actual', linestyle='--', alpha=0.65) # Plot full historical data
block_preds_inv.plot(label='Forecast', color='k', alpha=0.65)
plt.title('Darts LSTM Block Forecast vs Actuals')
plt.xlabel('Month')
plt.ylabel('Energy Consumption')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ## NeuralForecast Long-Term Multioutput

# %%
from neuralforecast import NeuralForecast
from neuralforecast.models import LSTM as NF_LSTM
from neuralforecast.losses.pytorch import MAE, MSE
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.callbacks import ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error

logger = TensorBoardLogger("nf_tensorboard_log", name="LSTM")
# Out:
# 2025-10-17 21:29:53,660	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# 2025-10-17 21:29:54,571	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.

# %%
nf_df = energy.copy().reset_index()
nf_df.rename(columns={'Month': 'ds'}, inplace=True)
nf_df['unique_id'] = 'energy' # Add a unique_id column for NeuralForecast
print(nf_df.head())
# Out:
#           ds         y unique_id
# 0 1973-01-01  1957.641    energy
# 1 1973-02-01  1712.143    energy
# 2 1973-03-01  1510.079    energy
# 3 1973-04-01  1183.421    energy
# 4 1973-05-01  1006.326    energy

# %%
WINDOW_SIZE = 24 # This is `input_size` in NeuralForecast terms
TEST_LENGTH = 12 # Number of steps to forecast, 'h' in NeuralForecast

train_nf = nf_df.iloc[:-TEST_LENGTH]
test_nf = nf_df.iloc[-TEST_LENGTH:]

print(train_nf.shape)
print(test_nf.shape)
# Out:
# (576, 3)
# (12, 3)

# %%
# Add checkpoint callback
checkpoint_callback = ModelCheckpoint(
    monitor="valid_loss",
    mode="min",
    save_top_k=1,
)

# %%
import math

batch_size = 32
steps_per_epoch = math.ceil(len(train_nf) / batch_size)
steps_per_epoch
# Out:
# 18

# %%
# NeuralForecast LSTM parameters
PATIENCE = 15
nf_lstm_params = {
    'h': TEST_LENGTH, # Forecast horizon 
    'input_size': WINDOW_SIZE, 
    'encoder_n_layers': 2, # Number of layers for the LSTM 
    'encoder_hidden_size': 32, # Hidden state units 
    'encoder_dropout': 0.2, # Dropout regularization applied to LSTM outputs 
    'max_steps': steps_per_epoch * 500, # to match 500 epochs like Keras and Darts
    'batch_size': batch_size, 
    'learning_rate': 0.001, 
    'num_lr_decays': PATIENCE//3,
    'early_stop_patience_steps': PATIENCE, # Number of validation iterations before early stopping 
    'val_check_steps': steps_per_epoch, # Number of training steps the model evaluates its performance on val set
    'scaler_type': 'standard', # Type of scaler for normalization 
    'random_seed': 42, # For reproducibility
    'logger': logger, # to use with TensorBoard
  #  'decoder_layers':0, # Set to zero to remove the MLP decoder layer.
    'enable_checkpointing': True,
    'recurrent': False, # True = Recursive while False = Direct
    'callbacks': [checkpoint_callback]
}
# Instantiate the NeuralForecast LSTM model
lstm = NF_LSTM(**nf_lstm_params)
# Out:
# Seed set to 42

# %%
# %%time
# Define the models to be used in NeuralForecast
models = [lstm]

# Create the NeuralForecast object
# The `freq` parameter time series alignment
nf_lstm_model = NeuralForecast(models=models, freq='MS')

# Fit the model. 
#NeuralForecast handles data splitting internally for validation
nf_lstm_model.fit(df=train_nf, val_size= 36)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | hist_encoder | LSTM          | 12.9 K | train
# 4 | mlp_decoder  | MLP           | 4.4 K  | train
# -------------------------------------------------------
# 17.3 K    Trainable params
# 0         Non-trainable params
# 17.3 K    Total params
# 0.069     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# Epoch 539: 100%|██████████| 1/1 [00:00<00:00, 20.56it/s, v_num=2, train_loss_step=0.211, train_loss_epoch=0.211, valid_loss=88.40]
# CPU times: user 7.29 s, sys: 2.35 s, total: 9.64 s
# Wall time: 15.8 s

# %%
# %load_ext tensorboard
# %tensorboard --logdir=nf_tensorboard_log/
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6008 (pid 40214), started 0:00:03 ago. (Use '!kill 40214' to kill it.)
#       <iframe id="tensorboard-frame-bdd640fb06671ad1" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-bdd640fb06671ad1");
#           const url = new URL("http://localhost");
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Make predictions. The `predict` method uses the `h` defined in the model.
# It forecasts from the end of the `df` used in `fit`.
nf_forecast = nf_lstm_model.predict()
len(nf_forecast)
# Out:
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]
# 12

# %%
nf_forecast.columns
# Out:
# Index(['unique_id', 'ds', 'LSTM'], dtype='object')

# %%
# Extract the predictions for our 'energy' unique_id and set the index
nf_forecast_df = nf_forecast[nf_forecast['unique_id'] == 'energy'].set_index('ds')
nf_forecast_df = nf_forecast_df[['LSTM']] # Select the 'LSTM' column, which contains the predictions
nf_forecast_df.head()
# Out:
#                    LSTM
# ds
# 2021-01-01  2264.063965
# 2021-02-01  2017.535645
# 2021-03-01  1767.371216
# 2021-04-01  1536.106567
# 2021-05-01  1522.890259

# %%
# Prepare the actual test data for plotting
test_nf.set_index('ds', inplace=True)

plt.figure(figsize=(16, 5))
test_nf['y'].plot(label='Actual', linestyle='--', alpha=0.65)
nf_forecast_df['LSTM'].plot(label='Forecast', color='k', alpha=0.65)
plt.title('NeuralForecast LSTM Multioutput Forecast vs Actuals')
plt.xlabel('Month')
plt.ylabel('Energy Consumption')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# Calculate metrics
mae_nf = mean_absolute_error(test_nf['y'], nf_forecast_df['LSTM'])
rmse_nf = np.sqrt(mean_squared_error(test_nf['y'], nf_forecast_df['LSTM']))

print(f"NeuralForecast Test Set MAE:  {mae_nf:.4f}")
print(f"NeuralForecast Test Set RMSE: {rmse_nf:.4f}")
# Out:
# NeuralForecast Test Set MAE:  117.4197
# NeuralForecast Test Set RMSE: 146.7713

# %% [markdown]
# ## There is More

# %% [markdown]
# ### Keras

# %%
# manually loading best weights
keras_lstm_model.load_weights('./logs/best_model.keras')

# %% [markdown]
# ### Darts

# %%
pred_scaled_lm = darts_lstm_model.predict(n=len(d_test), series=d_train_val_scaled)
pred_inv_lm = d_scaler.inverse_transform(pred_scaled_lm)

rmse_val = rmse(d_test, pred_inv_lm)
mae_val = mae(d_test, pred_inv_lm)
print(f"Darts Test Set MAE:  {mae_val:.4f}")
print(f"Darts Test Set RMSE: {rmse_val:.4f}")
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 102.74it/s]
# Darts Test Set MAE:  123.2744
# Darts Test Set RMSE: 172.2344

# %%
plt.figure(figsize=(16, 5))
d_test.plot(label='Actual', linestyle='--', alpha=0.65) # Plot full historical data
pred_inv_lm.plot(label='Forecast', color='k', alpha=0.65)
plt.title('Darts LSTM Forecast "Last Model" vs Actuals (Validation Set)')
plt.xlabel('Month')
plt.ylabel('Energy Consumption')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# ### NeuralForecast: Loading Best Model

# %%
# Rebuild parameters with early stopping disabled
reload_params = nf_lstm_params.copy()
reload_params.update({
    'max_steps': 0,                  # Prevent training
    'early_stop_patience_steps': -1, # Disable NeuralForecast's auto EarlyStopping
})
reload_params.pop('callbacks', None) # Remove any callback references
# Out:
# [<pytorch_lightning.callbacks.model_checkpoint.ModelCheckpoint at 0x360dbfcd0>,
#  <pytorch_lightning.callbacks.early_stopping.EarlyStopping at 0x360a39a10>]

# %%
checkpoint_path = 'nf_tensorboard_log/LSTM/version_0/checkpoints/epoch=269-step=270.ckpt'
nf_best_model = NF_LSTM.load_from_checkpoint(checkpoint_path, **reload_params )
# Out:
# Seed set to 42

# %%
nf_loaded = NeuralForecast(models=[nf_best_model], freq='MS')
nf_loaded.fit(df=train_nf, val_size=0)
# Out:
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | eval
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | hist_encoder | LSTM          | 12.9 K | train
# 4 | mlp_decoder  | MLP           | 4.4 K  | train
# -------------------------------------------------------
# 17.3 K    Trainable params
# 0         Non-trainable params
# 17.3 K    Total params
# 0.069     Total estimated model params size (MB)
# 9         Modules in train mode
# 1         Modules in eval mode
# `Trainer.fit` stopped: `max_steps=0` reached.

# %%
nf_best_preds = nf_loaded.predict()
# Extract the predictions for our 'energy' unique_id and set the index
nf_forecast_bm = nf_best_preds[nf_best_preds['unique_id'] == 'energy'].set_index('ds')
nf_forecast_bm = nf_forecast_bm[['LSTM']]

# Calculate metrics
mae_nf = mean_absolute_error(test_nf['y'], nf_forecast_bm['LSTM'])
rmse_nf = np.sqrt(mean_squared_error(test_nf['y'], nf_forecast_bm['LSTM']))

print(f"NeuralForecast Test Set MAE:  {mae_nf:.4f}")
print(f"NeuralForecast Test Set RMSE: {rmse_nf:.4f}")
# Out:
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 125.79it/s]
# NeuralForecast Test Set MAE:  133.8668
# NeuralForecast Test Set RMSE: 177.8046

# %%
plt.figure(figsize=(16, 5))
test_nf['y'].plot(label='Actual', linestyle='--', alpha=0.65)
nf_forecast_bm['LSTM'].plot(label='Forecast', color='k', alpha=0.65)
plt.title('NeuralForecast LSTM "Best Model" Forecast vs Actuals')
plt.xlabel('Month')
plt.ylabel('Energy Consumption')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# # Multivariate Time Series

# %% [markdown]
# Components Descriptions:
#
# * Value_NE5 : Households & SMEs electricity consumption (low voltage, grid level 7) in kWh
# * Value_NE7 : Business and services electricity consumption (medium voltage, grid level 5) in kWh
# * Hr [%Hr] : Relative humidity
# * RainDur [min] : Duration of precipitation (divided by 4 for conversion from hourly to quarter-hourly records)
# * T [°C] : Temperature
# * WD [°] : Wind direction
# * WVv [m/s] : Wind vector speed
# * p [hPa] : Air pressure
# * WVs [m/s] : Wind scalar speed
# * StrGlo [W/m2] : Global solar irradiation

# %% [markdown]
# ## Darts BlockRNNModel

# %%
from darts.metrics import rmse, mae
from darts.dataprocessing.transformers import Scaler
from darts.models import BlockRNNModel
from darts.datasets import ElectricityConsumptionZurichDataset

import pandas as pd
import numpy as np
from pytorch_lightning.callbacks import EarlyStopping
from sklearn.preprocessing import StandardScaler
import torch
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [14, 7]

# %%
zurich = (ElectricityConsumptionZurichDataset()
                .load()
                .resample(freq="D", 
                          method='mean')
                 .astype(np.float32))

# %%
type(zurich)
# Out:
# darts.timeseries.TimeSeries

# %%
cov = ["T [°C]", "StrGlo [W/m2]", "RainDur [min]", "Hr [%Hr]"]
target = ["Value_NE5"]

# %%
# convert to a pandas' DataFrame
zurich_df = zurich.to_dataframe() # will be used with NeuralForecast later
zurich_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2800 entries, 2015-01-01 to 2022-08-31
# Freq: D
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Value_NE5      2800 non-null   float32
#  1   Value_NE7      2800 non-null   float32
#  2   Hr [%Hr]       2800 non-null   float32
#  3   RainDur [min]  2800 non-null   float32
#  4   StrGlo [W/m2]  2800 non-null   float32
#  5   T [°C]         2800 non-null   float32
#  6   WD [°]         2800 non-null   float32
#  7   WVs [m/s]      2800 non-null   float32
#  8   WVv [m/s]      2800 non-null   float32
#  9   p [hPa]        2800 non-null   float32
# dtypes: float32(10)
# memory usage: 131.2 KB

# %%
zurich_df[cov+target].plot(subplots=True, figsize=(10,10));

# %%
from statsmodels.graphics.tsaplots import month_plot, quarter_plot

# Resample target to monthly/quarterly for clearer seasonality
monthly_target = zurich_df[target].resample('ME').mean()
quarterly_target = zurich_df[target].resample('QE').mean()

month_plot(monthly_target, ylabel='kWh')
plt.title('Monthly Seasonality: Avg. Electricity Consumption')
plt.show()

# %%
quarter_plot(quarterly_target, ylabel='kWh')
plt.title('Quarterly Seasonality: Avg. Electricity Consumption')
plt.show()

# %%
zurich_cov = zurich[cov]
zurich_en = zurich[target]

# %%
def split_ts(data, test_size, val_size):
    """
    Split time series data maintaining temporal order.
    
    Parameters:
    - test_size: number of periods for final testing
    - val_size: number of periods for validation
    """
    n_total = len(data)
    test_start = n_total - test_size
    val_start = test_start - val_size

    train = data[:val_start]
    val = data[val_start:test_start]
    test = data[test_start:]

    return train, val, test

# %%
# Create splits maintaining temporal order
d_zen_train, d_zen_val, d_zen_test = split_ts(zurich_en, 30, 160)

print(f'''
Zurich Energy train: {len(d_zen_train)}
Zurich Energy val : {len(d_zen_val)}
Zurich Energy test: {len(d_zen_test)}''')

d_cov_train, d_cov_val, d_cov_test = split_ts(zurich_cov, 30, 160)

print(f'''
Zurich Covariates train: {len(d_cov_train)}
Zurich Covariates val : {len(d_cov_val)}
Zurich Covariates test: {len(d_cov_test)}''')
# Out:
# Zurich Energy train: 2610
# Zurich Energy val : 160
# Zurich Energy test: 30
#
# Zurich Covariates train: 2610
# Zurich Covariates val : 160
# Zurich Covariates test: 30

# %%
scaler_target = Scaler(StandardScaler())

d_zen_train_sc= scaler_target.fit_transform(d_zen_train)
d_zen_val_sc = scaler_target.transform(d_zen_val)
d_zen_test_sc = scaler_target.transform(d_zen_test)

# Covariates time series 
scaler_cov = Scaler(StandardScaler())

d_cov_train_sc = scaler_cov.fit_transform(d_cov_train)
d_cov_val_sc = scaler_cov.transform(d_cov_val)
d_cov_test_sc = scaler_cov.transform(d_cov_test)

# %% [markdown]
# ### Define Model Params

# %%
PATIENCE=15
early_stopper = EarlyStopping(
    monitor="val_loss", 
    patience=PATIENCE,  
    min_delta=0.001,    
    mode='min',         
    verbose=True)

trainer_kwargs = {
    "callbacks": [early_stopper],
    "enable_progress_bar": True, 
    "accelerator":"auto"}

lr_scheduler_kwargs = {
        "mode": "min",
        "monitor": "val_loss",
        "factor": 0.2,
        "patience": PATIENCE//3, 
        "min_lr": 1e-6
    }

# %%
model = BlockRNNModel(
    model="LSTM",
    input_chunk_length=120, # (4 months) captures seasonal patterns
    output_chunk_length=30, # 30 matches forecast horizon
    n_rnn_layers=2,
    hidden_dim=32,
    dropout=0.2,
    batch_size=32,
    n_epochs=500,
    optimizer_kwargs={"lr": 0.001},
    model_name="Zur_BlockRNN",
    log_tensorboard=True,
    random_state=42,
    force_reset=True,
    save_checkpoints=True,
    lr_scheduler_cls=torch.optim.lr_scheduler.ReduceLROnPlateau,
    lr_scheduler_kwargs= lr_scheduler_kwargs,
    pl_trainer_kwargs=trainer_kwargs 
)

# %%
# %%time
# Fit the model with transformed target data and covariates
model.fit(
    series=d_zen_train_sc,
    past_covariates=d_cov_train_sc,
    val_series=d_zen_val_sc,
    val_past_covariates=d_cov_val_sc, 
    verbose=True)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name            | Type             | Params | Mode
# -------------------------------------------------------------
# 0 | criterion       | MSELoss          | 0      | train
# 1 | train_criterion | MSELoss          | 0      | train
# 2 | val_criterion   | MSELoss          | 0      | train
# 3 | train_metrics   | MetricCollection | 0      | train
# 4 | val_metrics     | MetricCollection | 0      | train
# 5 | rnn             | LSTM             | 13.4 K | train
# 6 | fc              | Sequential       | 33     | train
# -------------------------------------------------------------
# 13.5 K    Trainable params
# 0         Non-trainable params
# 13.5 K    Total params
# 0.054     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████| 77/77 [00:02<00:00, 29.87it/s, v_num=logs, train_loss=0.488, val_loss=0.496]
# Metric val_loss improved. New best score: 0.496
# Epoch 1: 100%|██████████| 77/77 [00:01<00:00, 51.41it/s, v_num=logs, train_loss=0.252, val_loss=0.139]
# Metric val_loss improved by 0.357 >= min_delta = 0.001. New best score: 0.139
# Epoch 2: 100%|██████████| 77/77 [00:01<00:00, 50.48it/s, v_num=logs, train_loss=0.201, val_loss=0.094]
# Metric val_loss improved by 0.045 >= min_delta = 0.001. New best score: 0.094
# Epoch 3: 100%|██████████| 77/77 [00:01<00:00, 52.78it/s, v_num=logs, train_loss=0.133, val_loss=0.0765]
# Metric val_loss improved by 0.017 >= min_delta = 0.001. New best score: 0.077
# Epoch 4: 100%|██████████| 77/77 [00:01<00:00, 52.94it/s, v_num=logs, train_loss=0.136, val_loss=0.069]
# Metric val_loss improved by 0.008 >= min_delta = 0.001. New best score: 0.069
# Epoch 5: 100%|██████████| 77/77 [00:01<00:00, 50.88it/s, v_num=logs, train_loss=0.170, val_loss=0.0666]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.067
# Epoch 6: 100%|██████████| 77/77 [00:01<00:00, 52.28it/s, v_num=logs, train_loss=0.174, val_loss=0.0636]
# Metric val_loss improved by 0.003 >= min_delta = 0.001. New best score: 0.064
# Epoch 7: 100%|██████████| 77/77 [00:01<00:00, 51.65it/s, v_num=logs, train_loss=0.167, val_loss=0.062]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.062
# Epoch 22: 100%|██████████| 77/77 [00:01<00:00, 50.99it/s, v_num=logs, train_loss=0.0991, val_loss=0.0679]
# Monitored metric val_loss did not improve in the last 15 records. Best score: 0.062. Signaling Trainer to stop.
# Epoch 22: 100%|██████████| 77/77 [00:01<00:00, 50.55it/s, v_num=logs, train_loss=0.0991, val_loss=0.0679]
# CPU times: user 22 s, sys: 2.93 s, total: 24.9 s
# Wall time: 36.3 s
# BlockRNNModel(output_chunk_shift=0, model=LSTM, hidden_dim=32, n_rnn_layers=2, hidden_fc_sizes=None, dropout=0.2, activation=ReLU, use_static_covariates=True, input_chunk_length=120, output_chunk_length=30, batch_size=32, n_epochs=500, optimizer_kwargs={'lr': 0.001}, model_name=Zur_BlockRNN, log_tensorboard=True, random_state=42, force_reset=True, save_checkpoints=True, lr_scheduler_cls=<class 'torch.optim.lr_scheduler.ReduceLROnPlateau'>, lr_scheduler_kwargs={'mode': 'min', 'monitor': 'val_loss', 'factor': 0.2, 'patience': 5, 'min_lr': 1e-06}, pl_trainer_kwargs={'callbacks': [<pytorch_lightning.callbacks.early_stopping.EarlyStopping object at 0x36bda3050>], 'enable_progress_bar': True, 'accelerator': 'auto'})

# %%
zen_best_model = model.load_from_checkpoint(
                               model_name="Zur_BlockRNN", 
                               best=True)
zen_best_model
# Out:
# BlockRNNModel(output_chunk_shift=0, model=LSTM, hidden_dim=32, n_rnn_layers=2, hidden_fc_sizes=None, dropout=0.2, activation=ReLU, use_static_covariates=True, input_chunk_length=120, output_chunk_length=30, batch_size=32, n_epochs=500, optimizer_kwargs={'lr': 0.001}, model_name=Zur_BlockRNN, log_tensorboard=True, random_state=42, force_reset=True, save_checkpoints=True, lr_scheduler_cls=<class 'torch.optim.lr_scheduler.ReduceLROnPlateau'>, lr_scheduler_kwargs={'mode': 'min', 'monitor': 'val_loss', 'factor': 0.2, 'patience': 5, 'min_lr': 1e-06}, pl_trainer_kwargs={'callbacks': [<pytorch_lightning.callbacks.early_stopping.EarlyStopping object at 0x360ee35d0>], 'enable_progress_bar': True, 'accelerator': 'auto'})

# %%
d_zen_train_val_sc = d_zen_train_sc.append(d_zen_val_sc)
d_cov_train_val_sc = d_cov_train_sc.append(d_cov_val_sc)

zen_forecast_sc = zen_best_model.predict(
    n=len(d_zen_test_sc),
    series=d_zen_train_val_sc,
    past_covariates=d_cov_train_val_sc)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  4.39it/s]

# %%
zen_forecast_inv = scaler_target.inverse_transform(zen_forecast_sc)
# zen_forecast_inv.plot()

# %%
plt.figure(figsize=(16, 5))
d_zen_test.plot(label='Actual', linestyle='-', alpha=0.65)
zen_forecast_inv.plot(label='Forecast', color='k', linestyle='--', alpha=0.65)
plt.title('Darts Zurich Energy Forecast vs Actuals (Test Set)')
plt.xlabel('Day')
plt.ylabel('Energy Consumption')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
rmse_val = rmse(d_zen_test, zen_forecast_inv)
mae_val = mae(d_zen_test, zen_forecast_inv)
print(f"Darts Test Set MAE:  {mae_val:.4f}")
print(f"Darts Test Set RMSE: {rmse_val:.4f}")
# Out:
# Darts Test Set MAE:  835.9444
# Darts Test Set RMSE: 1435.1460

# %% [markdown]
# ## NeuralForecast

# %%
from neuralforecast import NeuralForecast
from neuralforecast.models import LSTM as NF_LSTM
from neuralforecast.losses.pytorch import MAE, MSE
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.callbacks import ModelCheckpoint
from sklearn.metrics import mean_absolute_error, mean_squared_error

logger = TensorBoardLogger("nf_tensorboard_log", name="LSTM_Multi")

# %%
zurich_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2800 entries, 2015-01-01 to 2022-08-31
# Freq: D
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Value_NE5      2800 non-null   float32
#  1   Value_NE7      2800 non-null   float32
#  2   Hr [%Hr]       2800 non-null   float32
#  3   RainDur [min]  2800 non-null   float32
#  4   StrGlo [W/m2]  2800 non-null   float32
#  5   T [°C]         2800 non-null   float32
#  6   WD [°]         2800 non-null   float32
#  7   WVs [m/s]      2800 non-null   float32
#  8   WVv [m/s]      2800 non-null   float32
#  9   p [hPa]        2800 non-null   float32
# dtypes: float32(10)
# memory usage: 131.2 KB

# %%
zurich_nf_df = zurich_df[target+cov].reset_index()

# %%
zurich_nf_df.head()
# Out:
# component  Timestamp     Value_NE5    T [°C]  StrGlo [W/m2]  RainDur [min]  \
# 0         2015-01-01  22354.730469 -1.820833      20.546875       0.000000
# 1         2015-01-02  23320.701172  0.948750      26.653229       4.643125
# 2         2015-01-03  23192.982422  5.255208      15.165104       5.505625
# 3         2015-01-04  21553.050781  4.378438      47.625523       1.090417
# 4         2015-01-05  29087.230469  0.906563      84.143852       0.000000
#
# component   Hr [%Hr]
# 0          87.858643
# 1          91.988853
# 2          91.880836
# 3          78.207397
# 4          80.368645

# %%
zurich_nf_df.rename(columns={'Timestamp': 'ds', 'Value_NE5': 'y'}, inplace=True)
zurich_nf_df['unique_id'] = 'ZurichEnergy'
zurich_nf_df.head()
# Out:
# component         ds             y    T [°C]  StrGlo [W/m2]  RainDur [min]  \
# 0         2015-01-01  22354.730469 -1.820833      20.546875       0.000000
# 1         2015-01-02  23320.701172  0.948750      26.653229       4.643125
# 2         2015-01-03  23192.982422  5.255208      15.165104       5.505625
# 3         2015-01-04  21553.050781  4.378438      47.625523       1.090417
# 4         2015-01-05  29087.230469  0.906563      84.143852       0.000000
#
# component   Hr [%Hr]     unique_id
# 0          87.858643  ZurichEnergy
# 1          91.988853  ZurichEnergy
# 2          91.880836  ZurichEnergy
# 3          78.207397  ZurichEnergy
# 4          80.368645  ZurichEnergy

# %%
TEST_LENGTH=30
WINDOW_SIZE=120

nf_zurich_test = zurich_nf_df.iloc[-TEST_LENGTH:]
nf_zurich_train = zurich_nf_df.iloc[:-TEST_LENGTH]

# %%
import math

batch_size = 32
steps_per_epoch = math.ceil(len(nf_zurich_train) / batch_size)
steps_per_epoch
# Out:
# 87

# %%
# Add checkpoint callback
checkpoint_callback = ModelCheckpoint(
    monitor="valid_loss",
    mode="min",
    save_top_k=1)

# %%
# NeuralForecast LSTM parameters
PATIENCE = 15
nf_lstm_params = {
    'h': TEST_LENGTH, 
    'input_size': WINDOW_SIZE, 
    'encoder_n_layers': 2, 
    'encoder_hidden_size': 32, 
    'encoder_dropout': 0.2, 
    'max_steps': steps_per_epoch * 500, 
    'batch_size': batch_size, 
    'learning_rate': 0.001, 
    'num_lr_decays': PATIENCE//3,
    'early_stop_patience_steps': PATIENCE, 
    'val_check_steps': steps_per_epoch,
    'scaler_type': 'standard', 
    'random_seed': 42, 
    'logger': logger, 
    'enable_checkpointing': True,
    'callbacks': [checkpoint_callback],
    'hist_exog_list': cov 
}
# Instantiate the NeuralForecast LSTM model
nf_lstm = NF_LSTM(**nf_lstm_params)


# Define the models to be used in NeuralForecast
models = [nf_lstm]

# Create the NeuralForecast object
nf_lstm_model = NeuralForecast(models=models, freq='D')
# Out:
# Seed set to 42

# %%
# %%time
# Fit the model. 
#NeuralForecast handles data splitting internally for validation
nf_lstm_model.fit(df=nf_zurich_train, val_size= 160)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | hist_encoder | LSTM          | 13.4 K | train
# 4 | mlp_decoder  | MLP           | 4.4 K  | train
# -------------------------------------------------------
# 17.8 K    Trainable params
# 0         Non-trainable params
# 17.8 K    Total params
# 0.071     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# Epoch 1478: 100%|██████████| 1/1 [00:00<00:00, 16.14it/s, v_num=2, train_loss_step=0.196, train_loss_epoch=0.196, valid_loss=1.13e+3]
# CPU times: user 27 s, sys: 5.97 s, total: 33 s
# Wall time: 56.9 s

# %%
nf_pred = nf_lstm_model.predict()
# Out:
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  1.34it/s]

# %%
# Prepare the actual test data for plotting
nf_zurich_test.set_index('ds', inplace=True)

plt.figure(figsize=(16, 5))
nf_zurich_test['y'].plot(label='Actual', linestyle='--', alpha=0.65)
nf_pred.set_index('ds')['LSTM'].plot(label='Forecast', color='k', alpha=0.65)
plt.title('NeuralForecast Zurich Energy Forecas vs Actuals (Test Set)')
plt.xlabel('Month')
plt.ylabel('Energy Consumption')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
# Calculate metrics
mae_nf = mean_absolute_error(nf_zurich_test['y'], nf_pred['LSTM'])
rmse_nf = np.sqrt(mean_squared_error(nf_zurich_test['y'], nf_pred['LSTM']))

print(f"NeuralForecast Test Set MAE:  {mae_nf:.4f}")
print(f"NeuralForecast Test Set RMSE: {rmse_nf:.4f}")
# Out:
# NeuralForecast Test Set MAE:  1121.0948
# NeuralForecast Test Set RMSE: 1473.5518

# %% [markdown]
# ### There is more

# %%
import pandas as pd

def add_time_covariates(df, ds_col='ds'):
    """
    Given a DataFrame with a DateTime column, returns a new DataFrame with added time-related future covariates.
    
    Returns:
        pd.DataFrame: DataFrame with additional time covariate columns.
    """
    df = df.copy()
    
    # Feature engineering
    df['hour'] = df[ds_col].dt.hour
    df['dayofweek'] = df[ds_col].dt.dayofweek
    df['month'] = df[ds_col].dt.month
    df['is_weekend'] = df[ds_col].dt.dayofweek.isin([5, 6]).astype(int)

    return df


nf_zurich_train_fc = add_time_covariates(nf_zurich_train, 'ds')
nf_zurich_test_fc = add_time_covariates(nf_zurich_test.reset_index(), 'ds')

# %%
fc_cov = ['hour', 'dayofweek', 'month', 'is_weekend']

# %%
# %%time
# NeuralForecast LSTM parameters
nf_lstm_params_fc = {
    'h': TEST_LENGTH, 
    'input_size': WINDOW_SIZE, 
    'encoder_n_layers': 2, 
    'encoder_hidden_size': 32, 
    'encoder_dropout': 0.2, 
    'max_steps': steps_per_epoch * 500, 
    'batch_size': batch_size, 
    'learning_rate': 0.001, 
    'num_lr_decays': PATIENCE//3,
    'early_stop_patience_steps': PATIENCE, 
    'val_check_steps': steps_per_epoch,
    'scaler_type': 'standard', 
    'random_seed': 42, 
    'logger': logger, 
    'enable_checkpointing': True,
    'callbacks': [checkpoint_callback],
    'hist_exog_list': cov,
    'futr_exog_list': fc_cov 
}
# Instantiate the NeuralForecast LSTM model
nf_lstm_fc = NF_LSTM(**nf_lstm_params_fc)

# Define the models to be used in NeuralForecast
models_fc = [nf_lstm_fc]

# Create the NeuralForecast object
nf_lstm_model_fc = NeuralForecast(models=models_fc, freq='D')

nf_lstm_model_fc.fit(df=nf_zurich_train_fc, val_size= 160)
# Out:
# Seed set to 42
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | hist_encoder | LSTM          | 14.0 K | train
# 4 | mlp_decoder  | MLP           | 4.9 K  | train
# -------------------------------------------------------
# 18.8 K    Trainable params
# 0         Non-trainable params
# 18.8 K    Total params
# 0.075     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# Epoch 1478: 100%|██████████| 1/1 [00:00<00:00, 14.86it/s, v_num=3, train_loss_step=0.114, train_loss_epoch=0.114, valid_loss=1.05e+3]
# CPU times: user 29 s, sys: 6.59 s, total: 35.6 s
# Wall time: 59.5 s

# %%
fc_cov.extend(['unique_id', 'ds'])
fc_cov
# Out:
# ['hour', 'dayofweek', 'month', 'is_weekend', 'unique_id', 'ds']

# %%
fut_cov_df = nf_zurich_test_fc.loc[:, fc_cov] # extract future covariates
nf_pred_fc = nf_lstm_model_fc.predict(futr_df=fut_cov_df) # supply future covariates
# Out:
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  2.48it/s]

# %%
# Calculate metrics
mae_nf = mean_absolute_error(nf_zurich_test['y'], nf_pred_fc['LSTM'])
rmse_nf = np.sqrt(mean_squared_error(nf_zurich_test['y'], nf_pred_fc['LSTM']))

print(f"NeuralForecast Test Set MAE:  {mae_nf:.4f}")
print(f"NeuralForecast Test Set RMSE: {rmse_nf:.4f}")
# Out:
# NeuralForecast Test Set MAE:  717.4011
# NeuralForecast Test Set RMSE: 1374.3146

# %% [markdown]
# # Hyperparameter Tuning

# %% [markdown]
# ## Using Darts

# %%
# !pip install "optuna-integration[pytorch_lightning]"

# %%
import optuna

# %%
def objective(trial):
    # Suggest hyperparameters
    PATIENCE=15
    hidden_dim = trial.suggest_categorical("hidden_dim", [16, 32, 64])
    dropout = trial.suggest_float("dropout", 0.0, 0.3, step=0.1)
    lr = trial.suggest_categorical("lr", [1e-4, 1e-3, 1e-2])

    # Early stopping callback
    early_stopper = EarlyStopping(
        monitor="val_loss",
        patience=PATIENCE,
        min_delta=0.001,
        mode="min"
    )

    pl_trainer_kwargs = {
        "callbacks": [early_stopper],
        "accelerator": "auto"
    }

    lr_scheduler_kwargs = {
        "mode": "min",
        "monitor": "val_loss",
        "factor": 0.2,
        "patience": PATIENCE//3, 
        "min_lr": 1e-6
    }

    model_name = f"LSTMHyperTune_trial_{trial.number}"
    # Model instantiation
    model = BlockRNNModel(
        model="LSTM",
        input_chunk_length=120,
        output_chunk_length=30,
        n_rnn_layers=2,
        hidden_dim=hidden_dim,
        dropout=dropout,
        batch_size=32,
        n_epochs=500,
        optimizer_kwargs={"lr": lr},
        model_name=model_name,
        random_state=42,
        force_reset=True,
        save_checkpoints=True,
        loss_fn=torch.nn.L1Loss(), # to use MAE loss
        lr_scheduler_cls=torch.optim.lr_scheduler.ReduceLROnPlateau,
        lr_scheduler_kwargs= lr_scheduler_kwargs,
        pl_trainer_kwargs=pl_trainer_kwargs
    )

    # Fit the model
    model.fit(
        series=d_zen_train_sc,
        past_covariates=d_cov_train_sc,
        val_series=d_zen_val_sc,
        val_past_covariates=d_cov_val_sc,
        verbose=False
    )

    score = model.trainer.callback_metrics['val_loss'].item()

    return score

# %%
# %%time

sampler = optuna.samplers.TPESampler(seed=42)
study = optuna.create_study(direction="minimize", sampler=sampler)
study.optimize(objective, n_trials=10)

print("Best trial:")
print(study.best_trial.params)
print("Best Validation MAE:", study.best_value)
# Out:
# [I 2025-10-17 21:50:04,388] A new study created in memory with name: no-name-9b538287-6129-489d-bfb5-9c431c7d726f
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [I 2025-10-17 21:51:25,530] Trial 0 finished with value: 0.2573452591896057 and parameters: {'hidden_dim': 32, 'dropout': 0.2, 'lr': 0.0001}. Best is trial 0 with value: 0.2573452591896057.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [I 2025-10-17 21:52:56,459] Trial 1 finished with value: 0.28433629870414734 and parameters: {'hidden_dim': 16, 'dropout': 0.0, 'lr': 0.0001}. Best is trial 0 with value: 0.2573452591896057.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [I 2025-10-17 21:53:31,154] Trial 2 finished with value: 0.3255566358566284 and parameters: {'hidden_dim': 64, 'dropout': 0.2, 'lr': 0.01}. Best is trial 0 with value: 0.2573452591896057.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [I 2025-10-17 21:55:50,083] Trial 3 finished with value: 0.24191126227378845 and parameters: {'hidden_dim': 64, 'dropout': 0.1, 'lr': 0.0001}. Best is trial 3 with value: 0.24191126227378845.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [I 2025-10-17 21:56:17,581] Trial 4 finished with value: 0.33913829922676086 and parameters: {'hidden_dim': 64, 'dropout': 0.0, 'lr': 0.01}. Best is trial 3 with value: 0.24191126227378845.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [I 2025-10-17 21:56:39,856] Trial 5 finished with value: 0.30191871523857117 and parameters: {'hidden_dim': 16, 'dropout': 0.2, 'lr': 0.01}. Best is trial 3 with value: 0.24191126227378845.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [I 2025-10-17 21:57:05,150] Trial 6 finished with value: 0.2957439124584198 and parameters: {'hidden_dim': 32, 'dropout': 0.2, 'lr': 0.01}. Best is trial 3 with value: 0.24191126227378845.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [I 2025-10-17 21:57:27,709] Trial 7 finished with value: 0.25242865085601807 and parameters: {'hidden_dim': 32, 'dropout': 0.3, 'lr': 0.01}. Best is trial 3 with value: 0.24191126227378845.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [I 2025-10-17 21:57:58,635] Trial 8 finished with value: 0.327534556388855 and parameters: {'hidden_dim': 32, 'dropout': 0.1, 'lr': 0.01}. Best is trial 3 with value: 0.24191126227378845.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# [I 2025-10-17 21:58:26,141] Trial 9 finished with value: 0.33913829922676086 and parameters: {'hidden_dim': 64, 'dropout': 0.0, 'lr': 0.01}. Best is trial 3 with value: 0.24191126227378845.
# Best trial:
# {'hidden_dim': 64, 'dropout': 0.1, 'lr': 0.0001}
# Best Validation MAE: 0.24191126227378845
# CPU times: user 5min, sys: 27.8 s, total: 5min 27s
# Wall time: 8min 21s

# %%
study.best_trial.params
# Out:
# {'hidden_dim': 64, 'dropout': 0.1, 'lr': 0.0001}

# %%
best_params = study.best_trial.params
best_params
# Out:
# {'hidden_dim': 64, 'dropout': 0.1, 'lr': 0.0001}

# %%
PATIENCE=15
early_stopper = EarlyStopping(
    monitor="val_loss", 
    patience=PATIENCE,  
    min_delta=0.001,    
    mode='min',         
    verbose=True)

trainer_kwargs = {
    "callbacks": [early_stopper],
    "enable_progress_bar": True, 
    "accelerator":"auto"}

lr_scheduler_kwargs = {
        "mode": "min",
        "monitor": "val_loss",
        "factor": 0.2,
        "patience": PATIENCE//3, 
        "min_lr": 1e-6
    }

best_model = BlockRNNModel(
    model="LSTM",
    input_chunk_length=120,
    output_chunk_length=30,
    n_rnn_layers=2,
    hidden_dim=best_params['hidden_dim'],  # from Optuna
    dropout=best_params['dropout'],           # from Optuna
    batch_size=32,
    n_epochs=500,         
    optimizer_kwargs={"lr": best_params['lr']},  # from Optuna
    model_name="LSTMBestModel",
    random_state=42,
    force_reset=True,
    save_checkpoints=True,  # Set to True if you want to save checkpoints now
    loss_fn=torch.nn.L1Loss(),
    lr_scheduler_cls=torch.optim.lr_scheduler.ReduceLROnPlateau,
    lr_scheduler_kwargs= lr_scheduler_kwargs,
    pl_trainer_kwargs=trainer_kwargs)

# %%
# %%time
# Fit the model with transformed target data and covariates
best_model.fit(
    series=d_zen_train_sc,
    past_covariates=d_cov_train_sc,
    val_series=d_zen_val_sc,
    val_past_covariates=d_cov_val_sc, 
    verbose=True)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name            | Type             | Params | Mode
# -------------------------------------------------------------
# 0 | criterion       | L1Loss           | 0      | train
# 1 | train_criterion | L1Loss           | 0      | train
# 2 | val_criterion   | L1Loss           | 0      | train
# 3 | train_metrics   | MetricCollection | 0      | train
# 4 | val_metrics     | MetricCollection | 0      | train
# 5 | rnn             | LSTM             | 51.5 K | train
# 6 | fc              | Sequential       | 65     | train
# -------------------------------------------------------------
# 51.5 K    Trainable params
# 0         Non-trainable params
# 51.5 K    Total params
# 0.206     Total estimated model params size (MB)
# 8         Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████| 77/77 [00:01<00:00, 46.21it/s, train_loss=0.764, val_loss=0.714]
# Metric val_loss improved. New best score: 0.714
# Epoch 2: 100%|██████████| 77/77 [00:01<00:00, 48.40it/s, train_loss=0.644, val_loss=0.713]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.713
# Epoch 3: 100%|██████████| 77/77 [00:01<00:00, 48.06it/s, train_loss=0.528, val_loss=0.708]
# Metric val_loss improved by 0.005 >= min_delta = 0.001. New best score: 0.708
# Epoch 4: 100%|██████████| 77/77 [00:01<00:00, 48.53it/s, train_loss=0.498, val_loss=0.702]
# Metric val_loss improved by 0.006 >= min_delta = 0.001. New best score: 0.702
# Epoch 5: 100%|██████████| 77/77 [00:01<00:00, 48.11it/s, train_loss=0.436, val_loss=0.685]
# Metric val_loss improved by 0.017 >= min_delta = 0.001. New best score: 0.685
# Epoch 6: 100%|██████████| 77/77 [00:01<00:00, 46.80it/s, train_loss=0.382, val_loss=0.671]
# Metric val_loss improved by 0.014 >= min_delta = 0.001. New best score: 0.671
# Epoch 7: 100%|██████████| 77/77 [00:01<00:00, 48.90it/s, train_loss=0.387, val_loss=0.651]
# Metric val_loss improved by 0.020 >= min_delta = 0.001. New best score: 0.651
# Epoch 8: 100%|██████████| 77/77 [00:01<00:00, 46.56it/s, train_loss=0.360, val_loss=0.632]
# Metric val_loss improved by 0.019 >= min_delta = 0.001. New best score: 0.632
# Epoch 9: 100%|██████████| 77/77 [00:01<00:00, 48.27it/s, train_loss=0.320, val_loss=0.603]
# Metric val_loss improved by 0.029 >= min_delta = 0.001. New best score: 0.603
# Epoch 10: 100%|██████████| 77/77 [00:01<00:00, 47.94it/s, train_loss=0.302, val_loss=0.570]
# Metric val_loss improved by 0.033 >= min_delta = 0.001. New best score: 0.570
# Epoch 11: 100%|██████████| 77/77 [00:01<00:00, 48.70it/s, train_loss=0.295, val_loss=0.529]
# Metric val_loss improved by 0.041 >= min_delta = 0.001. New best score: 0.529
# Epoch 12: 100%|██████████| 77/77 [00:01<00:00, 46.62it/s, train_loss=0.294, val_loss=0.490]
# Metric val_loss improved by 0.039 >= min_delta = 0.001. New best score: 0.490
# Epoch 13: 100%|██████████| 77/77 [00:01<00:00, 48.46it/s, train_loss=0.295, val_loss=0.456]
# Metric val_loss improved by 0.034 >= min_delta = 0.001. New best score: 0.456
# Epoch 14: 100%|██████████| 77/77 [00:01<00:00, 48.49it/s, train_loss=0.333, val_loss=0.417]
# Metric val_loss improved by 0.039 >= min_delta = 0.001. New best score: 0.417
# Epoch 15: 100%|██████████| 77/77 [00:01<00:00, 48.38it/s, train_loss=0.266, val_loss=0.383]
# Metric val_loss improved by 0.034 >= min_delta = 0.001. New best score: 0.383
# Epoch 16: 100%|██████████| 77/77 [00:01<00:00, 48.40it/s, train_loss=0.268, val_loss=0.373]
# Metric val_loss improved by 0.010 >= min_delta = 0.001. New best score: 0.373
# Epoch 17: 100%|██████████| 77/77 [00:01<00:00, 49.29it/s, train_loss=0.305, val_loss=0.356]
# Metric val_loss improved by 0.018 >= min_delta = 0.001. New best score: 0.356
# Epoch 18: 100%|██████████| 77/77 [00:01<00:00, 47.35it/s, train_loss=0.288, val_loss=0.338]
# Metric val_loss improved by 0.018 >= min_delta = 0.001. New best score: 0.338
# Epoch 20: 100%|██████████| 77/77 [00:01<00:00, 48.60it/s, train_loss=0.260, val_loss=0.328]
# Metric val_loss improved by 0.010 >= min_delta = 0.001. New best score: 0.328
# Epoch 21: 100%|██████████| 77/77 [00:01<00:00, 49.06it/s, train_loss=0.232, val_loss=0.321]
# Metric val_loss improved by 0.007 >= min_delta = 0.001. New best score: 0.321
# Epoch 22: 100%|██████████| 77/77 [00:01<00:00, 50.34it/s, train_loss=0.249, val_loss=0.314]
# Metric val_loss improved by 0.008 >= min_delta = 0.001. New best score: 0.314
# Epoch 23: 100%|██████████| 77/77 [00:01<00:00, 47.84it/s, train_loss=0.247, val_loss=0.311]
# Metric val_loss improved by 0.003 >= min_delta = 0.001. New best score: 0.311
# Epoch 24: 100%|██████████| 77/77 [00:01<00:00, 49.20it/s, train_loss=0.201, val_loss=0.302]
# Metric val_loss improved by 0.008 >= min_delta = 0.001. New best score: 0.302
# Epoch 25: 100%|██████████| 77/77 [00:01<00:00, 47.73it/s, train_loss=0.202, val_loss=0.300]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.300
# Epoch 26: 100%|██████████| 77/77 [00:01<00:00, 48.69it/s, train_loss=0.249, val_loss=0.293]
# Metric val_loss improved by 0.007 >= min_delta = 0.001. New best score: 0.293
# Epoch 28: 100%|██████████| 77/77 [00:01<00:00, 48.53it/s, train_loss=0.255, val_loss=0.281]
# Metric val_loss improved by 0.012 >= min_delta = 0.001. New best score: 0.281
# Epoch 30: 100%|██████████| 77/77 [00:01<00:00, 49.29it/s, train_loss=0.223, val_loss=0.279]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.279
# Epoch 32: 100%|██████████| 77/77 [00:01<00:00, 47.54it/s, train_loss=0.246, val_loss=0.275]
# Metric val_loss improved by 0.005 >= min_delta = 0.001. New best score: 0.275
# Epoch 33: 100%|██████████| 77/77 [00:01<00:00, 48.30it/s, train_loss=0.212, val_loss=0.273]
# Metric val_loss improved by 0.001 >= min_delta = 0.001. New best score: 0.273
# Epoch 34: 100%|██████████| 77/77 [00:01<00:00, 46.83it/s, train_loss=0.251, val_loss=0.271]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.271
# Epoch 35: 100%|██████████| 77/77 [00:01<00:00, 48.71it/s, train_loss=0.251, val_loss=0.265]
# Metric val_loss improved by 0.006 >= min_delta = 0.001. New best score: 0.265
# Epoch 40: 100%|██████████| 77/77 [00:01<00:00, 47.62it/s, train_loss=0.223, val_loss=0.263]
# Metric val_loss improved by 0.003 >= min_delta = 0.001. New best score: 0.263
# Epoch 41: 100%|██████████| 77/77 [00:01<00:00, 47.89it/s, train_loss=0.187, val_loss=0.259]
# Metric val_loss improved by 0.004 >= min_delta = 0.001. New best score: 0.259
# Epoch 44: 100%|██████████| 77/77 [00:01<00:00, 47.30it/s, train_loss=0.194, val_loss=0.255]
# Metric val_loss improved by 0.004 >= min_delta = 0.001. New best score: 0.255
# Epoch 46: 100%|██████████| 77/77 [00:01<00:00, 48.11it/s, train_loss=0.214, val_loss=0.253]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.253
# Epoch 48: 100%|██████████| 77/77 [00:01<00:00, 48.09it/s, train_loss=0.223, val_loss=0.251]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.251
# Epoch 53: 100%|██████████| 77/77 [00:01<00:00, 48.48it/s, train_loss=0.214, val_loss=0.249]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.249
# Epoch 55: 100%|██████████| 77/77 [00:01<00:00, 47.45it/s, train_loss=0.192, val_loss=0.248]
# Metric val_loss improved by 0.001 >= min_delta = 0.001. New best score: 0.248
# Epoch 58: 100%|██████████| 77/77 [00:01<00:00, 49.06it/s, train_loss=0.182, val_loss=0.246]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.246
# Epoch 64: 100%|██████████| 77/77 [00:01<00:00, 46.70it/s, train_loss=0.174, val_loss=0.243]
# Metric val_loss improved by 0.003 >= min_delta = 0.001. New best score: 0.243
# Epoch 78: 100%|██████████| 77/77 [00:01<00:00, 47.66it/s, train_loss=0.178, val_loss=0.241]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.241
# Epoch 93: 100%|██████████| 77/77 [00:01<00:00, 47.63it/s, train_loss=0.167, val_loss=0.242]
# Monitored metric val_loss did not improve in the last 15 records. Best score: 0.241. Signaling Trainer to stop.
# Epoch 93: 100%|██████████| 77/77 [00:01<00:00, 47.23it/s, train_loss=0.167, val_loss=0.242]
# CPU times: user 1min 32s, sys: 12.3 s, total: 1min 45s
# Wall time: 2min 32s
# BlockRNNModel(output_chunk_shift=0, model=LSTM, hidden_dim=64, n_rnn_layers=2, hidden_fc_sizes=None, dropout=0.1, activation=ReLU, use_static_covariates=True, input_chunk_length=120, output_chunk_length=30, batch_size=32, n_epochs=500, optimizer_kwargs={'lr': 0.0001}, model_name=LSTMBestModel, random_state=42, force_reset=True, save_checkpoints=True, loss_fn=L1Loss(), lr_scheduler_cls=<class 'torch.optim.lr_scheduler.ReduceLROnPlateau'>, lr_scheduler_kwargs={'mode': 'min', 'monitor': 'val_loss', 'factor': 0.2, 'patience': 5, 'min_lr': 1e-06}, pl_trainer_kwargs={'callbacks': [<pytorch_lightning.callbacks.early_stopping.EarlyStopping object at 0x37778fb50>], 'enable_progress_bar': True, 'accelerator': 'auto'})

# %%
zen_best_model = best_model.load_from_checkpoint(
                               model_name="LSTMBestModel", 
                               best=True)
zen_best_model
# Out:
# BlockRNNModel(output_chunk_shift=0, model=LSTM, hidden_dim=64, n_rnn_layers=2, hidden_fc_sizes=None, dropout=0.1, activation=ReLU, use_static_covariates=True, input_chunk_length=120, output_chunk_length=30, batch_size=32, n_epochs=500, optimizer_kwargs={'lr': 0.0001}, model_name=LSTMBestModel, random_state=42, force_reset=True, save_checkpoints=True, loss_fn=L1Loss(), lr_scheduler_cls=<class 'torch.optim.lr_scheduler.ReduceLROnPlateau'>, lr_scheduler_kwargs={'mode': 'min', 'monitor': 'val_loss', 'factor': 0.2, 'patience': 5, 'min_lr': 1e-06}, pl_trainer_kwargs={'callbacks': [<pytorch_lightning.callbacks.early_stopping.EarlyStopping object at 0x3c60570d0>], 'enable_progress_bar': True, 'accelerator': 'auto'})

# %%
d_zen_train_val_sc = d_zen_train_sc.append(d_zen_val_sc)
d_cov_train_val_sc = d_cov_train_sc.append(d_cov_val_sc)

zen_forecast_sc = zen_best_model.predict(
    n=len(d_zen_test_sc),
    series=d_zen_train_val_sc,
    past_covariates=d_cov_train_val_sc)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 55.61it/s]

# %%
zen_forecast_inv = scaler_target.inverse_transform(zen_forecast_sc)
# zen_forecast_inv.plot()

# %%
plt.figure(figsize=(16, 5))
d_zen_test.plot(label='Actual', linestyle='-', alpha=0.65)
zen_forecast_inv.plot(label='Forecast', color='k', linestyle='--', alpha=0.65)
plt.title('Darts Zurich Energy Forecast vs Actuals (Test Set)')
plt.xlabel('Day')
plt.ylabel('Energy Consumption')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
rmse_val = rmse(d_zen_test, zen_forecast_inv)
mae_val = mae(d_zen_test, zen_forecast_inv)
print(f"Darts Test Set MAE:  {mae_val:.4f}")
print(f"Darts Test Set RMSE: {rmse_val:.4f}")
# Out:
# Darts Test Set MAE:  871.1782
# Darts Test Set RMSE: 1340.4065

# %%
zen_best_model.save("darts_tuned_model.pt")
model_loaded = BlockRNNModel.load("darts_tuned_model.pt")
model_loaded
# Out:
# BlockRNNModel(output_chunk_shift=0, model=LSTM, hidden_dim=64, n_rnn_layers=2, hidden_fc_sizes=None, dropout=0.1, activation=ReLU, use_static_covariates=True, input_chunk_length=120, output_chunk_length=30, batch_size=32, n_epochs=500, optimizer_kwargs={'lr': 0.0001}, model_name=LSTMBestModel, random_state=42, force_reset=True, save_checkpoints=True, loss_fn=L1Loss(), lr_scheduler_cls=<class 'torch.optim.lr_scheduler.ReduceLROnPlateau'>, lr_scheduler_kwargs={'mode': 'min', 'monitor': 'val_loss', 'factor': 0.2, 'patience': 5, 'min_lr': 1e-06}, pl_trainer_kwargs={'callbacks': [<pytorch_lightning.callbacks.early_stopping.EarlyStopping object at 0x37784f710>], 'enable_progress_bar': True, 'accelerator': 'auto'})

# %% [markdown]
# ## Using NeuralForecast

# %%
import optuna
from neuralforecast.auto import AutoLSTM

# %%
# Use this to disable training prints from optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)

# %%
import math

TEST_LENGTH=30
WINDOW_SIZE=120

batch_size = 32
steps_per_epoch = math.ceil(len(nf_zurich_train) / batch_size)

# NeuralForecast LSTM parameters
PATIENCE = 15
nf_lstm_params = {
    'input_size': WINDOW_SIZE, 
    'encoder_n_layers': 2, 
    'encoder_hidden_size': 32, 
    'encoder_dropout': 0.2, 
    'max_steps': steps_per_epoch * 500, 
    'batch_size': batch_size, 
    'learning_rate': 0.001, 
    'num_lr_decays': PATIENCE//3,
    'early_stop_patience_steps': PATIENCE, 
    'val_check_steps': steps_per_epoch, 
    'scaler_type': 'standard', 
    'random_seed': 42, #
    'hist_exog_list': cov 
}

# %%
configs = {**nf_lstm_params}
configs.update({'learning_rate': 1000})
configs.get('learning_rate')
# Out:
# 1000

# %%
def config_lstm(trial):
    # Start with a copy of the base parameters
    configs = {**nf_lstm_params}
	# Update with the hyperparameters to be tuned by Optuna
    configs.update(
        {"learning_rate": trial.suggest_categorical("learning_rate", [1e-4, 1e-3, 1e-2]),
         "encoder_hidden_size": trial.suggest_categorical("encoder_hidden_size", [16, 32, 64]),
         "encoder_dropout": trial.suggest_float("encoder_dropout", 0.0, 0.3, step=0.1)
        })

    return configs

# %%
hp_model = AutoLSTM(h=TEST_LENGTH,
                  loss=MAE(),
                  config=config_lstm,
                  search_alg=sampler, # defined in the Darts section
                  backend='optuna',
                  num_samples=10)

# %%
# %%time
nf_hp = NeuralForecast(models=[hp_model], freq='D')
nf_hp.fit(df=nf_zurich_train, val_size= 160)
# Out:
# Seed set to 42
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | hist_encoder | LSTM          | 3.6 K  | train
# 4 | mlp_decoder  | MLP           | 2.3 K  | train
# -------------------------------------------------------
# 6.0 K     Trainable params
# 0         Non-trainable params
# 6.0 K     Total params
# 0.024     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# Epoch 5132: 100%|██████████| 1/1 [00:00<00:00, 16.52it/s, v_num=12, train_loss_step=0.297, train_loss_epoch=0.297, valid_loss=873.0]
# Seed set to 42
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | hist_encoder | LSTM          | 3.6 K  | train
# 4 | mlp_decoder  | MLP           | 2.3 K  | train
# -------------------------------------------------------
# 6.0 K     Trainable params
# 0         Non-trainable params
# 6.0 K     Total params
# 0.024     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# Epoch 1652: 100%|██████████| 1/1 [00:00<00:00, 21.53it/s, v_num=13, train_loss_step=0.189, train_loss_epoch=0.189, valid_loss=962.0]
# Seed set to 42
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | hist_encoder | LSTM          | 13.4 K | train
# 4 | mlp_decoder  | MLP           | 4.4 K  | train
# -------------------------------------------------------
# 17.8 K    Trainable params
# 0         Non-trainable params
# 17.8 K    Total params
# 0.071     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# Epoch 1391: 100%|██████████| 1/1 [00:00<00:00, 15.45it/s, v_num=14, train_loss_step=0.0454, train_loss_epoch=0.0454, valid_loss=1.21e+3]
# Seed set to 42
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | hist_encoder | LSTM          | 3.6 K  | train
# 4 | mlp_decoder  | MLP           | 2.3 K  | train
# -------------------------------------------------------
# 6.0 K     Trainable params
# 0         Non-trainable params
# 6.0 K     Total params
# 0.024     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# Epoch 3653: 100%|██████████| 1/1 [00:00<00:00, 17.66it/s, v_num=15, train_loss_step=0.189, train_loss_epoch=0.189, valid_loss=1.09e+3]
# Seed set to 42
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | hist_encoder | LSTM          | 3.6 K  | train
# 4 | mlp_decoder  | MLP           | 2.3 K  | train
# -------------------------------------------------------
# 6.0 K     Trainable params
# 0         Non-trainable params
# 6.0 K     Total params
# 0.024     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# Epoch 1826: 100%|██████████| 1/1 [00:00<00:00, 17.46it/s, v_num=16, train_loss_step=0.262, train_loss_epoch=0.262, valid_loss=870.0]
# Seed set to 42
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | hist_encoder | LSTM          | 51.5 K | train
# 4 | mlp_decoder  | MLP           | 8.4 K  | train
# -------------------------------------------------------
# 59.9 K    Trainable params
# 0         Non-trainable params
# 59.9 K    Total params
# 0.240     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# Epoch 1391: 100%|██████████| 1/1 [00:00<00:00, 17.09it/s, v_num=17, train_loss_step=0.0178, train_loss_epoch=0.0178, valid_loss=1.04e+3]
# Seed set to 42
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | hist_encoder | LSTM          | 3.6 K  | train
# 4 | mlp_decoder  | MLP           | 2.3 K  | train
# -------------------------------------------------------
# 6.0 K     Trainable params
# 0         Non-trainable params
# 6.0 K     Total params
# 0.024     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# Epoch 5132: 100%|██████████| 1/1 [00:00<00:00, 16.46it/s, v_num=18, train_loss_step=0.297, train_loss_epoch=0.297, valid_loss=873.0]
# Seed set to 42
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | hist_encoder | LSTM          | 3.6 K  | train
# 4 | mlp_decoder  | MLP           | 2.3 K  | train
# -------------------------------------------------------
# 6.0 K     Trainable params
# 0         Non-trainable params
# 6.0 K     Total params
# 0.024     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# Epoch 3653: 100%|██████████| 1/1 [00:00<00:00, 20.78it/s, v_num=19, train_loss_step=0.213, train_loss_epoch=0.213, valid_loss=1.27e+3]
# Seed set to 42
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | hist_encoder | LSTM          | 3.6 K  | train
# 4 | mlp_decoder  | MLP           | 2.3 K  | train
# -------------------------------------------------------
# 6.0 K     Trainable params
# 0         Non-trainable params
# 6.0 K     Total params
# 0.024     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# Epoch 1652: 100%|██████████| 1/1 [00:00<00:00, 12.30it/s, v_num=20, train_loss_step=0.189, train_loss_epoch=0.189, valid_loss=962.0]
# Seed set to 42
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | hist_encoder | LSTM          | 13.4 K | train
# 4 | mlp_decoder  | MLP           | 4.4 K  | train
# -------------------------------------------------------
# 17.8 K    Trainable params
# 0         Non-trainable params
# 17.8 K    Total params
# 0.071     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# Epoch 1565: 100%|██████████| 1/1 [00:00<00:00, 16.40it/s, v_num=21, train_loss_step=0.188, train_loss_epoch=0.188, valid_loss=964.0]
# Seed set to 42
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name         | Type          | Params | Mode
# -------------------------------------------------------
# 0 | loss         | MAE           | 0      | train
# 1 | padder_train | ConstantPad1d | 0      | train
# 2 | scaler       | TemporalNorm  | 0      | train
# 3 | hist_encoder | LSTM          | 3.6 K  | train
# 4 | mlp_decoder  | MLP           | 2.3 K  | train
# -------------------------------------------------------
# 6.0 K     Trainable params
# 0         Non-trainable params
# 6.0 K     Total params
# 0.024     Total estimated model params size (MB)
# 10        Modules in train mode
# 0         Modules in eval mode
# Epoch 1826: 100%|██████████| 1/1 [00:00<00:00, 14.68it/s, v_num=22, train_loss_step=0.262, train_loss_epoch=0.262, valid_loss=870.0]
# CPU times: user 8min 34s, sys: 1min 45s, total: 10min 19s
# Wall time: 20min 16s

# %%
nf_hp.models[0].results.best_trial
# Out:
# FrozenTrial(number=4, state=1, values=[870.3497314453125], datetime_start=datetime.datetime(2025, 10, 17, 22, 17, 58, 609430), datetime_complete=datetime.datetime(2025, 10, 17, 22, 18, 58, 296738), params={'learning_rate': 0.001, 'encoder_hidden_size': 16, 'encoder_dropout': 0.3}, user_attrs={'ALL_PARAMS': {'input_size': 120, 'encoder_n_layers': 2, 'encoder_hidden_size': 16, 'encoder_dropout': 0.3, 'max_steps': 43500, 'batch_size': 32, 'learning_rate': 0.001, 'num_lr_decays': 5, 'early_stop_patience_steps': 15, 'val_check_steps': 87, 'scaler_type': 'standard', 'random_seed': 42, 'hist_exog_list': ['T [°C]', 'StrGlo [W/m2]', 'RainDur [min]', 'Hr [%Hr]'], 'h': 30, 'loss': MAE(), 'valid_loss': MAE()}, 'METRICS': {'loss': tensor(870.3497), 'train_loss': tensor(0.2622)}}, system_attrs={}, intermediate_values={}, distributions={'learning_rate': CategoricalDistribution(choices=(0.0001, 0.001, 0.01)), 'encoder_hidden_size': CategoricalDistribution(choices=(16, 32, 64)), 'encoder_dropout': FloatDistribution(high=0.3, log=False, low=0.0, step=0.1)}, trial_id=4, value=None)

# %%
nf_hp.models[0].results.best_trial.params
# Out:
# {'learning_rate': 0.001, 'encoder_hidden_size': 16, 'encoder_dropout': 0.3}

# %%
results = nf_hp.models[0].results.trials_dataframe()

# %%
results
# Out:
#    number        value             datetime_start          datetime_complete  \
# 0       0   873.367065 2025-10-17 22:11:18.592034 2025-10-17 22:14:11.506867
# 1       1   962.380127 2025-10-17 22:14:11.506894 2025-10-17 22:15:06.412548
# 2       2  1207.395630 2025-10-17 22:15:06.412572 2025-10-17 22:15:59.267182
# 3       3  1090.369507 2025-10-17 22:15:59.267214 2025-10-17 22:17:58.609390
# 4       4   870.349731 2025-10-17 22:17:58.609430 2025-10-17 22:18:58.296738
# 5       5  1040.810181 2025-10-17 22:18:58.296762 2025-10-17 22:19:54.319900
# 6       6   873.367065 2025-10-17 22:19:54.319928 2025-10-17 22:22:41.450817
# 7       7  1266.811890 2025-10-17 22:22:41.450843 2025-10-17 22:24:40.380134
# 8       8   962.380127 2025-10-17 22:24:40.380157 2025-10-17 22:26:16.009013
# 9       9   964.249084 2025-10-17 22:26:16.009063 2025-10-17 22:30:32.122665
#
#                 duration  params_encoder_dropout  params_encoder_hidden_size  \
# 0 0 days 00:02:52.914833                     0.3                          16
# 1 0 days 00:00:54.905654                     0.0                          16
# 2 0 days 00:00:52.854610                     0.0                          32
# 3 0 days 00:01:59.342176                     0.1                          16
# 4 0 days 00:00:59.687308                     0.3                          16
# 5 0 days 00:00:56.023138                     0.0                          64
# 6 0 days 00:02:47.130889                     0.3                          16
# 7 0 days 00:01:58.929291                     0.1                          16
# 8 0 days 00:01:35.628856                     0.0                          16
# 9 0 days 00:04:16.113602                     0.3                          32
#
#    params_learning_rate                              user_attrs_ALL_PARAMS  \
# 0                0.0001  {'input_size': 120, 'encoder_n_layers': 2, 'en...
# 1                0.0010  {'input_size': 120, 'encoder_n_layers': 2, 'en...
# 2                0.0100  {'input_size': 120, 'encoder_n_layers': 2, 'en...
# 3                0.0010  {'input_size': 120, 'encoder_n_layers': 2, 'en...
# 4                0.0010  {'input_size': 120, 'encoder_n_layers': 2, 'en...
# 5                0.0100  {'input_size': 120, 'encoder_n_layers': 2, 'en...
# 6                0.0001  {'input_size': 120, 'encoder_n_layers': 2, 'en...
# 7                0.0100  {'input_size': 120, 'encoder_n_layers': 2, 'en...
# 8                0.0010  {'input_size': 120, 'encoder_n_layers': 2, 'en...
# 9                0.0010  {'input_size': 120, 'encoder_n_layers': 2, 'en...
#
#                                   user_attrs_METRICS     state
# 0  {'loss': tensor(873.3671), 'train_loss': tenso...  COMPLETE
# 1  {'loss': tensor(962.3801), 'train_loss': tenso...  COMPLETE
# 2  {'loss': tensor(1207.3956), 'train_loss': tens...  COMPLETE
# 3  {'loss': tensor(1090.3695), 'train_loss': tens...  COMPLETE
# 4  {'loss': tensor(870.3497), 'train_loss': tenso...  COMPLETE
# 5  {'loss': tensor(1040.8102), 'train_loss': tens...  COMPLETE
# 6  {'loss': tensor(873.3671), 'train_loss': tenso...  COMPLETE
# 7  {'loss': tensor(1266.8119), 'train_loss': tens...  COMPLETE
# 8  {'loss': tensor(962.3801), 'train_loss': tenso...  COMPLETE
# 9  {'loss': tensor(964.2491), 'train_loss': tenso...  COMPLETE

# %%
results['user_attrs_ALL_PARAMS'][0]
# Out:
# {'input_size': 120,
#  'encoder_n_layers': 2,
#  'encoder_hidden_size': 16,
#  'encoder_dropout': 0.3,
#  'max_steps': 43500,
#  'batch_size': 32,
#  'learning_rate': 0.0001,
#  'num_lr_decays': 5,
#  'early_stop_patience_steps': 15,
#  'val_check_steps': 87,
#  'scaler_type': 'standard',
#  'random_seed': 42,
#  'hist_exog_list': ['T [°C]', 'StrGlo [W/m2]', 'RainDur [min]', 'Hr [%Hr]'],
#  'h': 30,
#  'loss': MAE(),
#  'valid_loss': MAE()}

# %%
results['user_attrs_METRICS'][0]
# Out:
# {'loss': tensor(873.3671), 'train_loss': tensor(0.2968)}

# %%
results.drop(columns='user_attrs_ALL_PARAMS')
# Out:
#    number        value             datetime_start          datetime_complete  \
# 0       0   873.367065 2025-10-17 22:11:18.592034 2025-10-17 22:14:11.506867
# 1       1   962.380127 2025-10-17 22:14:11.506894 2025-10-17 22:15:06.412548
# 2       2  1207.395630 2025-10-17 22:15:06.412572 2025-10-17 22:15:59.267182
# 3       3  1090.369507 2025-10-17 22:15:59.267214 2025-10-17 22:17:58.609390
# 4       4   870.349731 2025-10-17 22:17:58.609430 2025-10-17 22:18:58.296738
# 5       5  1040.810181 2025-10-17 22:18:58.296762 2025-10-17 22:19:54.319900
# 6       6   873.367065 2025-10-17 22:19:54.319928 2025-10-17 22:22:41.450817
# 7       7  1266.811890 2025-10-17 22:22:41.450843 2025-10-17 22:24:40.380134
# 8       8   962.380127 2025-10-17 22:24:40.380157 2025-10-17 22:26:16.009013
# 9       9   964.249084 2025-10-17 22:26:16.009063 2025-10-17 22:30:32.122665
#
#                 duration  params_encoder_dropout  params_encoder_hidden_size  \
# 0 0 days 00:02:52.914833                     0.3                          16
# 1 0 days 00:00:54.905654                     0.0                          16
# 2 0 days 00:00:52.854610                     0.0                          32
# 3 0 days 00:01:59.342176                     0.1                          16
# 4 0 days 00:00:59.687308                     0.3                          16
# 5 0 days 00:00:56.023138                     0.0                          64
# 6 0 days 00:02:47.130889                     0.3                          16
# 7 0 days 00:01:58.929291                     0.1                          16
# 8 0 days 00:01:35.628856                     0.0                          16
# 9 0 days 00:04:16.113602                     0.3                          32
#
#    params_learning_rate                                 user_attrs_METRICS  \
# 0                0.0001  {'loss': tensor(873.3671), 'train_loss': tenso...
# 1                0.0010  {'loss': tensor(962.3801), 'train_loss': tenso...
# 2                0.0100  {'loss': tensor(1207.3956), 'train_loss': tens...
# 3                0.0010  {'loss': tensor(1090.3695), 'train_loss': tens...
# 4                0.0010  {'loss': tensor(870.3497), 'train_loss': tenso...
# 5                0.0100  {'loss': tensor(1040.8102), 'train_loss': tens...
# 6                0.0001  {'loss': tensor(873.3671), 'train_loss': tenso...
# 7                0.0100  {'loss': tensor(1266.8119), 'train_loss': tens...
# 8                0.0010  {'loss': tensor(962.3801), 'train_loss': tenso...
# 9                0.0010  {'loss': tensor(964.2491), 'train_loss': tenso...
#
#       state
# 0  COMPLETE
# 1  COMPLETE
# 2  COMPLETE
# 3  COMPLETE
# 4  COMPLETE
# 5  COMPLETE
# 6  COMPLETE
# 7  COMPLETE
# 8  COMPLETE
# 9  COMPLETE

# %%
Y_hat_df_optuna = nf_hp.predict()
# Y_hat_df_optuna = Y_hat_df_optuna.reset_index()
# Y_hat_df_optuna.head()
# Out:
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00, 47.48it/s]

# %%
# Calculate metrics
mae_nf = mean_absolute_error(nf_zurich_test['y'], Y_hat_df_optuna['AutoLSTM'])
rmse_nf = np.sqrt(mean_squared_error(nf_zurich_test['y'], Y_hat_df_optuna['AutoLSTM']))

print(f"NeuralForecast Test Set MAE:  {mae_nf:.4f}")
print(f"NeuralForecast Test Set RMSE: {rmse_nf:.4f}")
# Out:
# NeuralForecast Test Set MAE:  782.5295
# NeuralForecast Test Set RMSE: 1273.3864

# %%
# Prepare the actual test data for plotting

plt.figure(figsize=(16, 5))
nf_zurich_test['y'].plot(label='Actual', linestyle='--', alpha=0.65)
Y_hat_df_optuna.set_index('ds')['AutoLSTM'].plot(label='Forecast', color='k', alpha=0.65)
plt.title('NeuralForecast Zurich Energy Forecas vs Actuals (Test Set)')
plt.xlabel('Month')
plt.ylabel('Energy Consumption')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
nf_hp.save("nf_tuned_model", overwrite=True)

# %%
from neuralforecast import NeuralForecast
nf_loaded = NeuralForecast.load("nf_tuned_model")
# Out:
# Seed set to 42

# %%
# nf_loaded.predict()

# %% [markdown]
# ## There is more

# %%
# !pip install plotly
#!pip install nbformat

from optuna.visualization import (plot_optimization_history, 
                                 plot_param_importances,
                                 plot_timeline,
                                 plot_slice)

# %%
# For darts
plot_optimization_history(study).show() 
plot_param_importances(study).show()    
plot_timeline(study).show() 
plot_slice(study).show()

# %%
# For NeuralForecast
nf_study = nf_hp.models[0].results

plot_optimization_history(nf_study).show()
plot_param_importances(nf_study).show()
plot_timeline(nf_study).show()
plot_slice(nf_study).show()

# %%
optuna.importance.get_param_importances(study)
# Out:
# {'lr': np.float64(0.5433718007544666),
#  'dropout': np.float64(0.2485593058694068),
#  'hidden_dim': np.float64(0.20806889337612663)}

# %%
optuna.importance.get_param_importances(nf_study)
# Out:
# {'learning_rate': np.float64(0.5599127718955856),
#  'encoder_dropout': np.float64(0.30231717390090374),
#  'encoder_hidden_size': np.float64(0.13777005420351063)}

# %% [markdown]
# # Forecasting with Temporal Convolutional Networks (TCN)

# %% [markdown]
# ## Using Darts TCNModel

# %%
from darts.models import TCNModel

# %%
PATIENCE=15
early_stopper = EarlyStopping(
    monitor="val_loss", 
    patience=PATIENCE,  
    min_delta=0.001,    
    mode='min',         
    verbose=True)

trainer_kwargs = {
    "callbacks": [early_stopper],
    "enable_progress_bar": True, 
    "accelerator":"auto"}

lr_scheduler_kwargs = {
        "mode": "min",
        "monitor": "val_loss",
        "factor": 0.2,
        "patience": PATIENCE//3, 
        "min_lr": 1e-6
    }

tcn_d_model = TCNModel(
    input_chunk_length=120,
    output_chunk_length=30,
    n_epochs=500,
    kernel_size=3, # TCNModel default
    num_filters=3, # TCNModel default
    dilation_base=2, # TCNModel default
    optimizer_kwargs={"lr": 0.001},
    weight_norm=True, # TCNModel default is False
    model_name="Zur_TCNModel",
    random_state=42,
    force_reset=True,
    save_checkpoints=True,
    lr_scheduler_cls=torch.optim.lr_scheduler.ReduceLROnPlateau,
    lr_scheduler_kwargs= lr_scheduler_kwargs,
    pl_trainer_kwargs=trainer_kwargs 
)

# %%
# %%time
# Fit the model with transformed target data and covariates
tcn_d_model.fit(
    series=d_zen_train_sc,
    past_covariates=d_cov_train_sc,
    val_series=d_zen_val_sc,
    val_past_covariates=d_cov_val_sc, 
    verbose=True)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name            | Type             | Params | Mode
# -------------------------------------------------------------
# 0 | criterion       | MSELoss          | 0      | train
# 1 | train_criterion | MSELoss          | 0      | train
# 2 | val_criterion   | MSELoss          | 0      | train
# 3 | train_metrics   | MetricCollection | 0      | train
# 4 | val_metrics     | MetricCollection | 0      | train
# 5 | res_blocks      | ModuleList       | 348    | train
# -------------------------------------------------------------
# 348       Trainable params
# 0         Non-trainable params
# 348       Total params
# 0.001     Total estimated model params size (MB)
# 63        Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████| 77/77 [00:03<00:00, 21.09it/s, train_loss=1.010, val_loss=0.690]
# Metric val_loss improved. New best score: 0.690
# Epoch 1: 100%|██████████| 77/77 [00:01<00:00, 66.20it/s, train_loss=0.774, val_loss=0.520]
# Metric val_loss improved by 0.170 >= min_delta = 0.001. New best score: 0.520
# Epoch 2: 100%|██████████| 77/77 [00:01<00:00, 70.27it/s, train_loss=0.673, val_loss=0.378]
# Metric val_loss improved by 0.141 >= min_delta = 0.001. New best score: 0.378
# Epoch 3: 100%|██████████| 77/77 [00:01<00:00, 69.30it/s, train_loss=0.545, val_loss=0.325]
# Metric val_loss improved by 0.053 >= min_delta = 0.001. New best score: 0.325
# Epoch 4: 100%|██████████| 77/77 [00:01<00:00, 70.29it/s, train_loss=0.504, val_loss=0.289]
# Metric val_loss improved by 0.037 >= min_delta = 0.001. New best score: 0.289
# Epoch 5: 100%|██████████| 77/77 [00:01<00:00, 69.85it/s, train_loss=0.464, val_loss=0.275]
# Metric val_loss improved by 0.014 >= min_delta = 0.001. New best score: 0.275
# Epoch 6: 100%|██████████| 77/77 [00:01<00:00, 69.45it/s, train_loss=0.405, val_loss=0.266]
# Metric val_loss improved by 0.009 >= min_delta = 0.001. New best score: 0.266
# Epoch 7: 100%|██████████| 77/77 [00:01<00:00, 70.65it/s, train_loss=0.436, val_loss=0.259]
# Metric val_loss improved by 0.006 >= min_delta = 0.001. New best score: 0.259
# Epoch 8: 100%|██████████| 77/77 [00:01<00:00, 67.20it/s, train_loss=0.410, val_loss=0.257]
# Metric val_loss improved by 0.002 >= min_delta = 0.001. New best score: 0.257
# Epoch 9: 100%|██████████| 77/77 [00:01<00:00, 68.17it/s, train_loss=0.384, val_loss=0.250]
# Metric val_loss improved by 0.007 >= min_delta = 0.001. New best score: 0.250
# Epoch 24: 100%|██████████| 77/77 [00:01<00:00, 68.93it/s, train_loss=0.348, val_loss=0.262]
# Monitored metric val_loss did not improve in the last 15 records. Best score: 0.250. Signaling Trainer to stop.
# Epoch 24: 100%|██████████| 77/77 [00:01<00:00, 67.03it/s, train_loss=0.348, val_loss=0.262]
# CPU times: user 24.9 s, sys: 3.96 s, total: 28.9 s
# Wall time: 32.9 s
# TCNModel(output_chunk_shift=0, kernel_size=3, num_filters=3, num_layers=None, dilation_base=2, weight_norm=True, dropout=0.2, input_chunk_length=120, output_chunk_length=30, n_epochs=500, optimizer_kwargs={'lr': 0.001}, model_name=Zur_TCNModel, random_state=42, force_reset=True, save_checkpoints=True, lr_scheduler_cls=<class 'torch.optim.lr_scheduler.ReduceLROnPlateau'>, lr_scheduler_kwargs={'mode': 'min', 'monitor': 'val_loss', 'factor': 0.2, 'patience': 5, 'min_lr': 1e-06}, pl_trainer_kwargs={'callbacks': [<pytorch_lightning.callbacks.early_stopping.EarlyStopping object at 0x3d4f43e50>], 'enable_progress_bar': True, 'accelerator': 'auto'})

# %%
tcn_best_model = tcn_d_model.load_from_checkpoint(
                               model_name="Zur_TCNModel", 
                               best=True)
tcn_best_model
# Out:
# TCNModel(output_chunk_shift=0, kernel_size=3, num_filters=3, num_layers=None, dilation_base=2, weight_norm=True, dropout=0.2, input_chunk_length=120, output_chunk_length=30, n_epochs=500, optimizer_kwargs={'lr': 0.001}, model_name=Zur_TCNModel, random_state=42, force_reset=True, save_checkpoints=True, lr_scheduler_cls=<class 'torch.optim.lr_scheduler.ReduceLROnPlateau'>, lr_scheduler_kwargs={'mode': 'min', 'monitor': 'val_loss', 'factor': 0.2, 'patience': 5, 'min_lr': 1e-06}, pl_trainer_kwargs={'callbacks': [<pytorch_lightning.callbacks.early_stopping.EarlyStopping object at 0x3d5399f90>], 'enable_progress_bar': True, 'accelerator': 'auto'})

# %%
d_zen_train_val_sc = d_zen_train_sc.append(d_zen_val_sc)
d_cov_train_val_sc = d_cov_train_sc.append(d_cov_val_sc)

tcn_forecast_sc = tcn_best_model.predict(
    n=len(d_zen_test),
    series=d_zen_train_val_sc,
    past_covariates=d_cov_train_val_sc)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  2.40it/s]

# %%
tcn_forecast_inv = scaler_target.inverse_transform(tcn_forecast_sc)

# %%
rmse_val = rmse(d_zen_test, tcn_forecast_inv)
mae_val = mae(d_zen_test, tcn_forecast_inv)
print(f"Darts Test Set MAE:  {mae_val:.4f}")
print(f"Darts Test Set RMSE: {rmse_val:.4f}")
# Out:
# Darts Test Set MAE:  744.4603
# Darts Test Set RMSE: 1331.7764

# %%
plt.figure(figsize=(16, 5))
d_zen_test.plot(label='Actual', linestyle='-', alpha=0.65)
tcn_forecast_inv.plot(label='Forecast', color='k', linestyle='--', alpha=0.65)
plt.title('Darts Zurich Energy TCN Forecast vs Actuals (Test Set)')
plt.xlabel('Day')
plt.ylabel('Energy Consumption')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
len(tcn_best_model.model.res_blocks)
# Out:
# 5

# %%
tcn_best_model.model.res_blocks[1]
# Out:
# _ResidualBlock(
#   (dropout1): MonteCarloDropout(p=0.2, inplace=False)
#   (dropout2): MonteCarloDropout(p=0.2, inplace=False)
#   (conv1): ParametrizedConv1d(
#     3, 3, kernel_size=(3,), stride=(1,), dilation=(2,)
#     (parametrizations): ModuleDict(
#       (weight): ParametrizationList(
#         (0): _WeightNorm()
#       )
#     )
#   )
#   (conv2): ParametrizedConv1d(
#     3, 3, kernel_size=(3,), stride=(1,), dilation=(2,)
#     (parametrizations): ModuleDict(
#       (weight): ParametrizationList(
#         (0): _WeightNorm()
#       )
#     )
#   )
# )

# %%
import math
# Parameters from our model
input_chunk_length = 120
dilation_base = 2
kernel_size = 3

# Darts' internal calculation for num_layers
num_layers = math.ceil(
    math.log(
        (input_chunk_length - 1) * (dilation_base - 1) / (kernel_size - 1) / 2 + 1,
        dilation_base,
    )
)

print(f"Calculated number of layers: {num_layers}")
# Out:
# Calculated number of layers: 5

# %% [markdown]
# ## There is more

# %%
d_zen_test.shape
# Out:
# (30, 1, 1)

# %%
# check activation function
tcn_prob = tcn_best_model.predict(  
    n=len(d_zen_test),
    num_samples=200,
    mc_dropout=True, # Enable MC Dropout
    series=d_zen_train_val_sc,
    past_covariates=d_cov_train_val_sc,
    random_state=1)

tcn_prob_inv = scaler_target.inverse_transform(tcn_prob)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  5.77it/s]

# %%
tcn_prob_inv.shape
# Out:
# (30, 1, 200)

# %%
plt.figure(figsize=(16, 5))
d_zen_test.plot(label='Actual', linestyle='-', alpha=0.65)
tcn_prob_inv.plot(label='Forecast', 
                  color='k', 
                  linestyle='--', 
                  alpha=0.25, 
                  low_quantile=0.05, 
                  high_quantile=0.95, 
                  central_quantile=0.5)
plt.title('Darts Zurich Energy TCN Probabilistic Forecast vs Actuals (Test Set)')
plt.xlabel('Day')
plt.ylabel('Energy Consumption')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %%
rmse_val = rmse(d_zen_test, tcn_prob_inv)
mae_val = mae(d_zen_test, tcn_prob_inv)
print(f"Darts Test Set MAE:  {mae_val:.4f}")
print(f"Darts Test Set RMSE: {rmse_val:.4f}")
# Out:
# Darts Test Set MAE:  755.3407
# Darts Test Set RMSE: 1342.8009

# %%
from darts.metrics import ql, mql
import numpy as np

# Ensure you are using the inverse-transformed forecast
# tcn_prob_inv = scaler_target.inverse_transform(tcn_prob)

# Calculate the loss for the lower bound (5th percentile)
loss_p05 = np.mean(ql(d_zen_test, tcn_prob_inv, q=0.05))

# Calculate the loss for the median (50th percentile)
# This value will be identical to your MAE score
loss_p50 = np.mean(ql(d_zen_test, tcn_prob_inv, q=0.50))

# Calculate the loss for the upper bound (95th percentile)
loss_p95 = np.mean(ql(d_zen_test, tcn_prob_inv, q=0.95))

print(f"Average Quantile Loss at 5th percentile:  {loss_p05:.4f}")
print(f"Average Quantile Loss at 50th percentile (MAE): {loss_p50:.4f}")
print(f"Average Quantile Loss at 95th percentile: {loss_p95:.4f}")
# Out:
# Average Quantile Loss at 5th percentile:  516.3424
# Average Quantile Loss at 50th percentile (MAE): 755.3407
# Average Quantile Loss at 95th percentile: 237.9668

# %%
# Ensure you are using the inverse-transformed forecast
# tcn_prob_inv = scaler_target.inverse_transform(tcn_prob)

# Calculate the loss for the lower bound (5th percentile)
loss_p05 = mql(d_zen_test, tcn_prob_inv, q=0.05)

# Calculate the loss for the median (50th percentile)
# This value will be identical to your MAE score
loss_p50 = mql(d_zen_test, tcn_prob_inv, q=0.50)

# Calculate the loss for the upper bound (95th percentile)
loss_p95 = mql(d_zen_test, tcn_prob_inv, q=0.95)

print(f"Average Quantile Loss at 5th percentile:  {loss_p05:.4f}")
print(f"Average Quantile Loss at 50th percentile (MAE): {loss_p50:.4f}")
print(f"Average Quantile Loss at 95th percentile: {loss_p95:.4f}")
# Out:
# Average Quantile Loss at 5th percentile:  516.3424
# Average Quantile Loss at 50th percentile (MAE): 755.3407
# Average Quantile Loss at 95th percentile: 237.9668

# %% [markdown]
# # NHITS

# %% [markdown]
# ## Using Darts

# %%
from darts.models import NHiTSModel

# %%
PATIENCE=15
early_stopper = EarlyStopping(
    monitor="val_loss", 
    patience=PATIENCE,  
    min_delta=0.001,    
    mode='min',         
    verbose=True)

trainer_kwargs = {
    "callbacks": [early_stopper],
    "enable_progress_bar": True, 
    "accelerator":"auto"}

lr_scheduler_kwargs = {
        "mode": "min",
        "monitor": "val_loss",
        "factor": 0.2,
        "patience": PATIENCE//3, 
        "min_lr": 1e-6
    }

nhits_d_model = NHiTSModel(
    input_chunk_length=120,
    output_chunk_length=30,
    n_epochs=500,
    num_blocks=1, # NHiTSModel default 
    num_stacks=3, # NHiTSModel default 
    num_layers=2, # NHiTSModel default 
    pooling_kernel_sizes=None, # NHiTSModel default 
    n_freq_downsample=None, # NHiTSModel default 
    optimizer_kwargs={"lr": 0.001},
    model_name="Zur_NHITSModel",
    random_state=42,
    force_reset=True,
    save_checkpoints=True,
    lr_scheduler_cls=torch.optim.lr_scheduler.ReduceLROnPlateau,
    lr_scheduler_kwargs= lr_scheduler_kwargs,
    pl_trainer_kwargs=trainer_kwargs
)

# %%
# %%time
# Fit the model with transformed target data and covariates
nhits_d_model.fit(
    series=d_zen_train_sc,
    past_covariates=d_cov_train_sc,
    val_series=d_zen_val_sc,
    val_past_covariates=d_cov_val_sc, 
    verbose=True)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name            | Type             | Params | Mode
# -------------------------------------------------------------
# 0 | criterion       | MSELoss          | 0      | train
# 1 | train_criterion | MSELoss          | 0      | train
# 2 | val_criterion   | MSELoss          | 0      | train
# 3 | train_metrics   | MetricCollection | 0      | train
# 4 | val_metrics     | MetricCollection | 0      | train
# 5 | stacks          | ModuleList       | 1.7 M  | train
# -------------------------------------------------------------
# 1.4 M     Trainable params
# 307 K     Non-trainable params
# 1.7 M     Total params
# 6.738     Total estimated model params size (MB)
# 42        Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████| 77/77 [00:02<00:00, 27.76it/s, train_loss=0.225, val_loss=0.0824]
# Metric val_loss improved. New best score: 0.082
# Epoch 15: 100%|██████████| 77/77 [00:00<00:00, 89.43it/s, train_loss=0.0518, val_loss=0.120]
# Monitored metric val_loss did not improve in the last 15 records. Best score: 0.082. Signaling Trainer to stop.
# Epoch 15: 100%|██████████| 77/77 [00:00<00:00, 85.52it/s, train_loss=0.0518, val_loss=0.120]
# CPU times: user 12.7 s, sys: 3.01 s, total: 15.7 s
# Wall time: 17.1 s
# NHiTSModel(output_chunk_shift=0, num_stacks=3, num_blocks=1, num_layers=2, layer_widths=512, pooling_kernel_sizes=None, n_freq_downsample=None, dropout=0.1, activation=ReLU, MaxPool1d=True, input_chunk_length=120, output_chunk_length=30, n_epochs=500, optimizer_kwargs={'lr': 0.001}, model_name=Zur_NHITSModel, random_state=42, force_reset=True, save_checkpoints=True, lr_scheduler_cls=<class 'torch.optim.lr_scheduler.ReduceLROnPlateau'>, lr_scheduler_kwargs={'mode': 'min', 'monitor': 'val_loss', 'factor': 0.2, 'patience': 5, 'min_lr': 1e-06}, pl_trainer_kwargs={'callbacks': [<pytorch_lightning.callbacks.early_stopping.EarlyStopping object at 0x3d53991d0>], 'enable_progress_bar': True, 'accelerator': 'auto'})

# %%
nhits_best_model = nhits_d_model.load_from_checkpoint(
                               model_name="Zur_NHITSModel", 
                               best=True)
nhits_best_model
# Out:
# NHiTSModel(output_chunk_shift=0, num_stacks=3, num_blocks=1, num_layers=2, layer_widths=512, pooling_kernel_sizes=None, n_freq_downsample=None, dropout=0.1, activation=ReLU, MaxPool1d=True, input_chunk_length=120, output_chunk_length=30, n_epochs=500, optimizer_kwargs={'lr': 0.001}, model_name=Zur_NHITSModel, random_state=42, force_reset=True, save_checkpoints=True, lr_scheduler_cls=<class 'torch.optim.lr_scheduler.ReduceLROnPlateau'>, lr_scheduler_kwargs={'mode': 'min', 'monitor': 'val_loss', 'factor': 0.2, 'patience': 5, 'min_lr': 1e-06}, pl_trainer_kwargs={'callbacks': [<pytorch_lightning.callbacks.early_stopping.EarlyStopping object at 0x3ee291810>], 'enable_progress_bar': True, 'accelerator': 'auto'})

# %%
d_zen_train_val_sc = d_zen_train_sc.append(d_zen_val_sc)
d_cov_train_val_sc = d_cov_train_sc.append(d_cov_val_sc)

nhits_forecast_sc = nhits_best_model.predict(
    n=len(d_zen_test),
    series=d_zen_train_val_sc,
    past_covariates=d_cov_train_val_sc)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Predicting DataLoader 0: 100%|██████████| 1/1 [00:00<00:00,  1.94it/s]

# %%
nhits_forecast_inv = scaler_target.inverse_transform(nhits_forecast_sc)

rmse_val = rmse(d_zen_test, nhits_forecast_inv)
mae_val = mae(d_zen_test, nhits_forecast_inv)
print(f"Darts Test Set MAE:  {mae_val:.4f}")
print(f"Darts Test Set RMSE: {rmse_val:.4f}")
# Out:
# Darts Test Set MAE:  672.2498
# Darts Test Set RMSE: 1221.2898

# %%
nhits_d_model.model
# Out:
# _NHiTSModule(
#   (criterion): MSELoss()
#   (train_criterion): MSELoss()
#   (val_criterion): MSELoss()
#   (train_metrics): MetricCollection,
#     prefix=train_
#   )
#   (val_metrics): MetricCollection,
#     prefix=val_
#   )
#   (stacks): ModuleList(
#     (0): _Stack(
#       (blocks): ModuleList(
#         (0): _Block(
#           (activation): ReLU()
#           (pooling_layer): MaxPool1d(kernel_size=60, stride=60, padding=0, dilation=1, ceil_mode=True)
#           (layers): Sequential(
#             (0): Linear(in_features=10, out_features=512, bias=True)
#             (1): ReLU()
#             (2): MonteCarloDropout(p=0.1, inplace=False)
#             (3): Linear(in_features=512, out_features=512, bias=True)
#             (4): ReLU()
#             (5): MonteCarloDropout(p=0.1, inplace=False)
#           )
#           (backcast_linear_layer): Linear(in_features=512, out_features=40, bias=True)
#           (forecast_linear_layer): Linear(in_features=512, out_features=10, bias=True)
#         )
#       )
#     )
#     (1): _Stack(
#       (blocks): ModuleList(
#         (0): _Block(
#           (activation): ReLU()
#           (pooling_layer): MaxPool1d(kernel_size=7, stride=7, padding=0, dilation=1, ceil_mode=True)
#           (layers): Sequential(
#             (0): Linear(in_features=86, out_features=512, bias=True)
#             (1): ReLU()
#             (2): MonteCarloDropout(p=0.1, inplace=False)
#             (3): Linear(in_features=512, out_features=512, bias=True)
#             (4): ReLU()
#             (5): MonteCarloDropout(p=0.1, inplace=False)
#           )
#           (backcast_linear_layer): Linear(in_features=512, out_features=200, bias=True)
#           (forecast_linear_layer): Linear(in_features=512, out_features=50, bias=True)
#         )
#       )
#     )
#     (2): _Stack(
#       (blocks): ModuleList(
#         (0): _Block(
#           (activation): ReLU()
#           (pooling_layer): MaxPool1d(kernel_size=1, stride=1, padding=0, dilation=1, ceil_mode=True)
#           (layers): Sequential(
#             (0): Linear(in_features=600, out_features=512, bias=True)
#             (1): ReLU()
#             (2): MonteCarloDropout(p=0.1, inplace=False)
#             (3): Linear(in_features=512, out_features=512, bias=True)
#             (4): ReLU()
#             (5): MonteCarloDropout(p=0.1, inplace=False)
#           )
#           (backcast_linear_layer): Linear(in_features=512, out_features=600, bias=True)
#           (forecast_linear_layer): Linear(in_features=512, out_features=150, bias=True)
#         )
#       )
#     )
#   )
# )

# %%
input_chunk_length = 120
num_blocks = 1 
num_stacks = 3
max_v = max(input_chunk_length // 2, 1)
pooling_kernel_sizes = tuple(
                (int(v),) * num_blocks
                for v in max_v // np.geomspace(1, max_v, num_stacks))
pooling_kernel_sizes
# Out:
# ((60,), (7,), (1,))

# %%
output_chunk_length = 30
max_v = max(output_chunk_length // 2, 1)
n_freq_downsample = tuple(
    (int(v),) * num_blocks
    for v in max_v // np.geomspace(1, max_v, num_stacks))
n_freq_downsample
# Out:
# ((15,), (3,), (1,))

# %% [markdown]
# ## There's more

# %%
nhits_historical_forecasts_sc = nhits_best_model.historical_forecasts(
    series=d_zen_train_val_sc,        
    past_covariates=d_cov_train_val_sc, 
    start=len(d_zen_train_sc), # where to start              
    forecast_horizon=30,       # Predict 30 steps ahead
    stride=1,                  # Move 1 step forward for each new forecast
    retrain=False,                    
    last_points_only=False # Get all forecast windows, not just the last points
)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
len(nhits_historical_forecasts_sc)
# Out:
# 131

# %%
from darts.metrics import mae

# Reverse the scaling for forecasts and targets
nhits_historical_forecasts_inv = [scaler_target.inverse_transform(forecast) for forecast in nhits_historical_forecasts_sc]

# Gather ground truth for comparison
# Let's get the corresponding "actual" future values for each forecast window
actuals = []
for i, forecast in enumerate(nhits_historical_forecasts_sc):
    # The forecast starts at the same time as forecast
    actual_values = d_zen_train_val_sc.slice(
        forecast.start_time(), forecast.end_time()
    )
    actuals.append(scaler_target.inverse_transform(actual_values))

# Compute MAE for each window, then average
window_maes = [mae(a, f) for a, f in zip(actuals, nhits_historical_forecasts_inv)]
average_mae = sum(window_maes) / len(window_maes)

print(f"Average rolling MAE over all windows: {average_mae:.2f}")
# Out:
# Average rolling MAE over all windows: 983.42

# %%
mae_scores = nhits_best_model.backtest(metric=mae, 
                          reduction=None, 
                          last_points_only=False, 
                          stride=1, 
                          start=len(d_zen_train_sc),
                          series=d_zen_train_val_sc, 
                          past_covariates=d_cov_train_val_sc,
                          forecast_horizon=30,
                          retrain=False)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
len(mae_scores)
# Out:
# 131

# %%
from darts.utils.statistics import plot_hist

plot_hist(mae_scores, bins=20)

# %%
avg_score = nhits_best_model.backtest(metric=mae, 
                          reduction=np.mean, 
                          last_points_only=True, 
                          stride=1, 
                          start=len(d_zen_train_sc),
                          series=d_zen_train_val_sc, 
                          past_covariates=d_cov_train_val_sc,
                          forecast_horizon=30,
                          retrain=False)
avg_score
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# np.float32(0.30740514)

# %%
from darts.utils.statistics import plot_residuals_analysis
plot_residuals_analysis(
        nhits_best_model.residuals(
                            retrain=False, 
                            series=d_zen_train_val_sc, 
                            past_covariates=d_cov_train_val_sc))
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
